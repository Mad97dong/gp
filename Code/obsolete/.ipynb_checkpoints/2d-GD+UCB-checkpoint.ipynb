# %%
import numpy as np
from numpy import linalg as LA
# %matplotlib inline
import matplotlib.pyplot as pl
from mpl_toolkits.mplot3d.axes3d import Axes3D

from PIL import Image
from scipy.optimize import minimize
import f_class
from GP import GP
from GP_grad import GP_grad
from GD import GD
import time
import imageio
from utils import *
from torch.quasirandom import SobolEngine
import sobol_seq

# %% [markdown]
# #### Noiseless & Noisy

# %%
Noise = False # Specify if noisy or not
Noise_level = 0.00 # if noisy, what is the noise sd
'''If use the scaled X and y, rememeber to scale the noise as well'''
# Out:
# 'If use the scaled X and y, rememeber to scale the noise as well'

# %% [markdown]
# #### High-dimensional function $f$

# %%
objective = f_class.sincos(Noise, Noise_level)
# objective = f_class.Branin(Noise, Noise_level)
# objective = f_class.Keane(Noise, Noise_level)
# objective = f_class.Rosenbrock_2(Noise, Noise_level)  
# objective = f_class.Griewank(Noise, Noise_level)
# objective = f_class.Alpine(Noise, Noise_level)
# objective = f_class.Shubert_2(Noise, Noise_level)
objective = f_class.Ackley_2(Noise, Noise_level)
# objective = f_class.Schwefel(Noise, Noise_level)
# objective = f_class.Michalewicz(Noise, Noise_level)
# objective = f_class.Levy(Noise, Noise_level)
# objective = f_class.quad(Noise, Noise_level)
# objective = f_class.Eggholder(Noise, Noise_level)
# objective = f_class.Rastrigin(Noise, Noise_level, dim=2)


f = objective.func
clean_f = lambda x: f_class.sincos().func(x)
# clean_f = lambda x: f_class.Branin().func(x)
# clean_f = lambda x: f_class.Keane().func(x)
# clean_f = lambda x: f_class.Rosenbrock_2().func(x)
# clean_f = lambda x: f_class.Griewank().func(x)
# clean_f = lambda x: f_class.Alpine().func(x)
clean_f = lambda x: f_class.Shubert_2().func(x)
clean_f = lambda x: f_class.Ackley_2().func(x)  
# clean_f = lambda x: f_class.Schwefel().func(x)
# clean_f = lambda x: f_class.Michalewicz().func(x)
# clean_f = lambda x: f_class.Levy().func(x)
# clean_f = lambda x: f_class.quad().func(x)
# clean_f = lambda x: f_class.Eggholder().func(x)
# clean_f = lambda x: f_class.Rastrigin().func(x)



B = np.array([item[1] for item in sorted(objective.bounds.items(), key=lambda x: x[0])], dtype=np.float64)
print(B) 
lb = B[:, 0]; ub = B[:, 1]
# print(f( np.array([1, 1]) ))
# np.sin(np.array([2, 1]))

dim = objective.input_dim
print('dim: ', dim)
# Out:
# [[-6.  6.]
#  [-6.  6.]]
# dim:  2

# %% [markdown]
# #### Finding Optimized Hyperparameter $\sigma, \ell \rightarrow$ Online Update of Hyperparameter

# %%
# set seed
seed = 0
def random_draw(n_random_draws=3):
    """ samples some points"""
    # should draw randomly
    return np.random.uniform(lb, ub, size=(n_random_draws, dim))


def optimize_hyper(lb, ub, sample_size=2000):
#     np.random.seed(seed)
    X = np.asarray(np.random.uniform(lb, ub, size=(sample_size, dim)))
    gp.set_data(X, f(X))
    ls, var = gp.optimize()
    gp.clear()
    return (ls, var)

# %%
# # find optimized hyper, if online, skip this part
# gp = GP_grad(B, Noise, Noise_level)
# (ls, var) = optimize_hyper(lb, ub, sample_size=3000)
# del gp
# (ls, var)

# %% [markdown]
# ##### Sampling

# %%
def unique_row(X):
    """
    A functions to trim repeated rows that may appear when optimizing.
    :param X: array to trim repeated rows from
    :return: mask of unique rows
    """
    # Sort array and kep track of where things should go back to
    order = np.lexsort(X.T)
    reorder = np.argsort(order)
    X = X[order]
    diff = np.diff(X, axis=0)
    U = np.ones(len(X), 'bool')
    U[1:] = (diff != 0).any(axis=1)
    return U[reorder]

class close_data():
    def __init__(self, Xc, eps=1):
        self.Xc = Xc
        self.eps = eps
        
    # Iterable
    def __iter__(self):
        return self
    
    # Iterator
    def __next__(self):
        Xn = self.Xc + self.eps*np.random.uniform(-1, 1, self.Xc.shape)
        return Xn
    
def is_new(Xn, Xpast=None):
    if Xpast is None:
        return True
    else:
        return np.array([(i != Xn).any() for i in Xpast]).all()

    
def close_draw(Xc, n_random_draws=4, close=1, Xpast=None):
    # sample from a small 2d box with center given Xc, no repeated points
    X = np.zeros((n_random_draws, dim))
    X[0] = Xc
    counter = 0
    gc = close_data(Xc)
    while True:
        Xn = next(gc)
        if LA.norm(Xn - Xc) > 5e-2 and is_new(Xn, Xpast) == True:
            counter += 1
            X[counter] = Xn
        if counter == n_random_draws-1:
            break
    return X

# %% [markdown]
# #### Grid & Plot

# %%
# creating meshgrid to plot over entire range
n_Grid = 100
x1 = np.linspace(lb[0], ub[0], n_Grid)
x2 = np.linspace(lb[1], ub[1], n_Grid)

X1, X2 = np.meshgrid(x1, x2)
Grid = np.vstack((X1.flatten(), X2.flatten())).T
Grid.shape
# Out:
# (10000, 2)

# %%
# 3d plot of the test function
from numpy import arange
from numpy import meshgrid
from matplotlib import pyplot
from matplotlib.pyplot import figure
# compute targets
results = f(Grid).reshape(X1.shape)
# create a surface plot with the jet color scheme
figure = pyplot.figure(figsize=(14, 8), dpi=80)
axis = figure.gca(projection='3d')
axis.plot_surface(X1, X2, results, cmap='jet')
# show the plot
pyplot.show()
f(Grid).shape
# Out:
# (10000, 1)

# %%
# 3d plot of the gradient
# approximate the gradient
from scipy import optimize

# optimize.approx_fprime(x, clean_Ackley_1d, eps)
eps = np.sqrt(np.finfo(float).eps)
approx_grad = np.array([optimize.approx_fprime(x, lambda x: clean_f(x).item(), eps) for x in Grid])
approx_grad.shape
g1 = approx_grad[:, 0]
g2 = approx_grad[:, 1]
g1, g2
# Out:
# (array([-0.60238814,  4.52933776,  4.69414222, ..., -4.69414282,
#         -4.52933705,  0.60238874]),
#  array([-0.60238814, -0.61588585, -0.62960386, ...,  0.62960446,
#          0.61588657,  0.60238874]))

# %%
# create a surface plot with the jet color scheme
figure = pyplot.figure(figsize=(14, 8), dpi=80)
axis = figure.gca(projection='3d')
axis.plot_surface(X1, X2, g1.reshape(X1.shape), cmap='jet')
# show the plot
pyplot.show()

# create a surface plot with the jet color scheme
figure = pyplot.figure(figsize=(14, 8), dpi=80)
axis = figure.gca(projection='3d')
axis.plot_surface(X1, X2, g2.reshape(X1.shape), cmap='jet')
# show the plot
pyplot.show()

# %% [markdown]
# # *BO Test*

# %%
MAX = 500 # function observations

# %% [markdown]
# ## GD

# %% [markdown]
# #### Set up

# %%
# initial data
setup = 1
X = np.asarray(np.random.uniform(lb, ub, size=(setup, dim)))
# w = X[np.argmin(f(X))].reshape(1, dim)

# # sample from a small 2d box
# Xc = np.asarray(np.random.uniform(lb, ub, size=(1, dim)))
# X = close_draw(Xc, n_random_draws=setup)
# X_fix = X

# %%
gp = GP_grad(B, Noise, Noise_level, compress=False)
# gp.set_hyper(ls, var) # if online, skip

gp.set_data(X, f(X))

gp.optimize()
gp.fit()

history = []

# %% [markdown]
# ##### warm up with UCB

# %%
# warmup = 3
# history_warmup = []
# for i in range(1, warmup+1):
#     b = np.log(i)
#     w, fw = gp.ucb_minimize(b)
#     X = np.vstack([X, w])
    
#     print(i, end = ', ')
#     print('w: ', w, end = ', ')
#     print('f(w): ', f(w).item(), end = ', ')
#     print()
    
#     gp.add_data(w.reshape(1, dim), f(w))
    
#     if i % 5 == 0:
#         ls, var = gp.optimize()
#         print('  # Optimal (ls, var) = ', (ls, var))
#     gp.fit()
#     history_warmup.append( (w, f(w)) )
    
# X_fix = X

# %% [markdown]
# ##### warm up with TS

# %%
warmup = 2
history_warmup = []
for i in range(1, warmup+1):
    w = gp.Thompson_sample()    
    X = np.vstack([X, w])
    
    print(i, end = ', ')
    print('w: ', w, end = ', ')
    print('f(w): ', f(w).item(), end = ', ')
    print()
    
    gp.add_data(w.reshape(1, dim), f(w))
    
    if i % 3 == 0:
        ls, var = gp.optimize()
        print('  # Optimal (ls, var) = ', (ls, var))
    gp.fit()
    history_warmup.append( (w, f(w)) )
    
X_fix = X
# Out:
# 1, w:  [5.9831779  2.77997088], f(w):  13.045580280301408,
# 2, w:  [-0.59251213 -1.75268376], f(w):  6.658621394018656,

# %%
# # fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6)) = pl.subplots(3, 2, figsize=(20, 12))
# x = Grid[:,0]
# y = Grid[:,1]

# # Posterior
# mu, covar = gp.posterior(Grid)
# mu = np.squeeze(mu)
# s = np.sqrt(np.diag(covar))

# fig, (ax1, ax2) = pl.subplots(1, 2, figsize=(25, 8))

# # plot function
# im = ax2.pcolormesh(X1, X2, s.reshape(X1.shape), cmap="jet", shading='auto')
# fig.colorbar(im, ax=ax2)

# im1 = ax1.contour(X1, X2, clean_f(Grid).reshape(X1.shape),  cmap="PuBuGn") 
# im2 = ax1.contour(X1, X2, mu.reshape(X1.shape), cmap="YlOrRd")
# # im2 = ax1.contour(X1, X2, clean_f(Grid).reshape(X1.shape), cmap="YlOrRd")

# pl.clabel(im1, inline=True, fontsize=8)

# fig.colorbar(im1, ax=ax1)
# fig.colorbar(im2, ax=ax1)

# ax1.plot(np.squeeze(gp.X[:, 0]), np.squeeze(gp.X[:, 1]), 'ko', linewidth=2)

# ax1.title.set_text("Noisy Ackley via posterior derivative mean")
# ax2.title.set_text("Standard deviation")
# pl.show()

# %%
# pl.figure(figsize=(13, 8), dpi=80)
# pl.plot(np.squeeze(np.array(history_warmup)[:, 1]), "-^")
# pl.xlabel("cost")
# pl.ylabel("function value")
# pl.grid(True)

# %% [markdown]
# ##### optimize with GD

# %%
w = gp.X[np.argmin(gp.y)]
optimizer = GD(gp, B, w, f)

# %%
gp.posterior(w), f(w)
# gp.grad_sample(w), optimize.approx_fprime(np.squeeze(w), lambda x: clean_f(x).item(), eps)
# Out:
# ((array([[6.65862139]]), array([[9.99999372e-09]])), array([[6.65862139]]))

# %%
optimize.approx_fprime(np.squeeze(w), lambda x: clean_f(x).item(), eps)
# Out:
# array([0.4481461 , 0.02316594])

# %%
gp.optimize()
np.set_printoptions(precision=4)
stall = False
cost = setup + warmup
desc = -optimizer._grad()

lr_const = 0.005
lr = lr_const

# create a candidate list of GD points from all queried points so far
optimizerHouse = [GD(gp, B, w, f) for w in gp.X]
while cost <= MAX:
    print(cost, end = '. ')
    # maintain best val so far
    y_best = np.min(f(gp.X))
    delta = np.abs(1e-2 * y_best)
    
    maxPI = 0
#     minEI = 0
    for i in range(len(optimizerHouse)):
        # if optimizer fail > stop loop, never pick that local GD
        if optimizerHouse[i].contFail <= optimizerHouse[i].stop and optimizerHouse[i].stop != 0:
            w, desc = optimizerHouse[i].update_sample(y_best=y_best - delta, lr=lr)
#             # EI
#             if gp.EI(w, y_best) < minEI and cost > 20:
#                 minEI = gp.EI(w, y_best)
#                 bestW = w
#                 bestIndex = i
            # PI
            if gp.PI(w, y_best) > maxPI:
                maxPI = gp.PI(w, y_best)
                bestW = w
                bestIndex = i
                
    if np.random.uniform(0, 1, 1).item() < maxPI and cost > 15:
        print('GD suggests with Pr = ', maxPI)
        print('   GD (i, loop) ', (bestIndex, len(optimizerHouse[bestIndex].history_full_w) ))
        w = bestW
#     if np.abs(minEI) > delta:
#         print('GD suggests with EI = ', minEI)
#         print('   GD (i, loop) ', (bestIndex, len(optimizerHouse[bestIndex].history_full_w) ))
#         w = bestW
    else:
        # UCB draw
        b = (cost)**4
        b = np.log(cost**gp.dim)
        w, _ = gp.ucb_minimize(b)
        print('UCB suggests with (1 - Pr) = ', 1 - maxPI)
#         print('UCB suggests with EI = ', minEI)
        
        optimizerHouse.append(GD(gp, B, w, f))
        print('   UCB create new index ', len(optimizerHouse) - 1)
    
    if is_new(w, gp.X) == False:
        raise ValueError('  ? hit past points')
    
    
    gp.add_data(w.reshape(1, -1), f(w))
    cost += 1
        
    # online hyper udpate + fitting GP with new query w
    if cost % 3 == 0:
        ls, var = gp.optimize()
        gp.set_hyper(ls, var)
        print('  # Optimal (ls, var) = ', (ls, var))
    gp.fit()
    
    history.append( (w, f(w)) )
    m, v = gp.posterior_full_grad('full', dim*[w])
    v = np.sqrt(np.diag(v))
    print('    w: ', np.squeeze(w), end = ', ')
    print('    f(w): %.4f ' % f(w).item())
    print('     d(w): ', np.squeeze(m), end = ', ')
    print('    s.d: ', np.squeeze(v), end = ', ')
    print('    g(w):', optimize.approx_fprime(np.squeeze(w), lambda x: clean_f(x).item(), eps))
    print('    y best:', y_best)
    print()
        
    
print('Max Cost reached = ', cost)
# history.append(optimizer.history_w)
# history_f.append([f(w).item() for w in optimizer.history_w])
# Out:
# 3. UCB suggests with (1 - Pr) =  0.4547794182712904
#    UCB create new index  3
#     w:  [-6.  6.],     f(w): 13.9761
#      d(w):  [ 9.6763e-05 -1.3853e-04],     s.d:  [5. 5.],     g(w): [-0.6024  0.6024]
#
# 4. UCB suggests with (1 - Pr) =  0.37561753277893095
#    UCB create new index  4
#     w:  [-6. -6.],     f(w): 13.9761
#      d(w):  [0.0335 0.0163],     s.d:  [4.9999 4.9999],     g(w): [-0.6024 -0.6024]
#
# 5. UCB suggests with (1 - Pr) =  0.3791152631300556
#    UCB create new index  5
#   # Optimal (ls, var) =  (2.0, 100.0)
#     w:  [0.5058 6.    ],     f(w): 13.1828
#      d(w):  [-0.0005 -0.0717],     s.d:  [4.9986 4.9997],     g(w): [-0.0129  1.2028]
#
# 6. UCB suggests with (1 - Pr) =  0.3767891021555225
#    UCB create new index  6
#     w:  [-6.      0.0649],     f(w): 11.5488
#      d(w):  [0.1135 0.002 ],     s.d:  [4.9945 4.9938],     g(w): [-1.2106  3.2645]
#
# 7. UCB suggests with (1 - Pr) =  1
#    UCB create new index  7
#     w:  [ 6.     -2.9201],     f(w): 12.3788
#      d(w):  [-0.622   0.0269],     s.d:  [4.9715 4.9868],     g(w): [0.9898 3.3813]
#
# 8. UCB suggests with (1 - Pr) =  1
#    UCB create new index  8
#   # Optimal (ls, var) =  (2.0, 100.0)
#     w:  [-1.6414  2.0855],     f(w): 7.8559
#      d(w):  [-0.1385  0.3443],     s.d:  [4.9262 4.7382],     g(w): [1.5319 3.3292]
#
# 9. UCB suggests with (1 - Pr) =  1
#    UCB create new index  9
#     w:  [2.3138 0.6239],     f(w): 7.8912
#      d(w):  [0.4763 0.2105],     s.d:  [4.6414 4.8152],     g(w): [ 3.6125 -0.7465]
#
# 10. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  10
#     w:  [6. 6.],     f(w): 13.9761
#      d(w):  [-0.4219 -2.0608],     s.d:  [4.9898 4.441 ],     g(w): [0.6024 0.6024]
#
# 11. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  11
#   # Optimal (ls, var) =  (2.0, 100.0)
#     w:  [-2.0717 -6.    ],     f(w): 11.9821
#      d(w):  [-0.194   0.6495],     s.d:  [4.5306 4.9159],     g(w): [-3.9139 -1.0895]
#
# 12. UCB suggests with (1 - Pr) =  0.9999999999997815
#    UCB create new index  12
#     w:  [ 6. -6.],     f(w): 13.9761
#      d(w):  [-0.8105  2.1244],     s.d:  [4.9199 4.3443],     g(w): [ 0.6024 -0.6024]
#
# 13. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  13
#     w:  [-3.7134 -2.5231],     f(w): 11.5745
#      d(w):  [-0.981  -0.6035],     s.d:  [4.1975 4.4487],     g(w): [ 0.4246 -0.5951]
#
# 14. UCB suggests with (1 - Pr) =  1
#    UCB create new index  14
#   # Optimal (ls, var) =  (2.0, 100.0)
#     w:  [-2.732  6.   ],     f(w): 13.2873
#      d(w):  [-0.1393 -0.6023],     s.d:  [3.9393 4.8361],     g(w): [4.4035 1.0132]
#
# 15. UCB suggests with (1 - Pr) =  1
#    UCB create new index  15
#     w:  [-6.      2.9299],     f(w): 12.3477
#      d(w):  [0.899  0.7341],     s.d:  [4.8723 3.5228],     g(w): [-0.9886 -2.9903]
#
# 16. UCB suggests with (1 - Pr) =  1
#    UCB create new index  16
#     w:  [ 6.     -0.1144],     f(w): 11.7566
#      d(w):  [-0.8212  0.2997],     s.d:  [4.7285 3.2619],     g(w): [ 1.2103 -4.9915]
#
# 17. UCB suggests with (1 - Pr) =  1
#    UCB create new index  17
#   # Optimal (ls, var) =  (2.0, 90.63960170037478)
#     w:  [2.5419 3.6016],     f(w): 11.5832
#      d(w):  [0.507  0.9465],     s.d:  [4.0897 3.6696],     g(w): [0.5366 0.4657]
#
# 18. UCB suggests with (1 - Pr) =  1
#    UCB create new index  18
#     w:  [ 2.6156 -2.1183],     f(w): 9.2985
#      d(w):  [ 1.0112 -1.2564],     s.d:  [3.7614 3.2822],     g(w): [-0.7091 -3.2196]
#
# 19. UCB suggests with (1 - Pr) =  1
#    UCB create new index  19
#     w:  [-2.7397  0.0502],     f(w): 7.5861
#      d(w):  [-1.6227 -0.3569],     s.d:  [3.3803 2.8212],     g(w): [2.9627 1.5522]
#
# 20. UCB suggests with (1 - Pr) =  1
#    UCB create new index  20
#   # Optimal (ls, var) =  (2.0, 79.09685850795466)
#     w:  [-0.0088  0.4903],     f(w): 3.0581
#      d(w):  [0.1836 0.5253],     s.d:  [2.2787 2.5868],     g(w): [-0.222   2.8298]
#
# 21. GD suggests with Pr =  0.46568335497641455
#    GD (i, loop)  (20, 2)
#     w:  [-0.0038  0.4904],     f(w): 3.0575
#      d(w):  [-0.1208  0.4991],     s.d:  [0.0467 2.5843],     g(w): [-0.0966  2.8289]
#
# 22. UCB suggests with (1 - Pr) =  0.4170065299760414
#    UCB create new index  21
#     w:  [-6.     -2.9151],     f(w): 12.3962
#      d(w):  [ 1.6427 -0.8732],     s.d:  [3.1222 3.1582],     g(w): [-0.9904  3.5694]
#
# 23. UCB suggests with (1 - Pr) =  0.43454184552359054
#    UCB create new index  22
#   # Optimal (ls, var) =  (2.0, 68.22892254601184)
#     w:  [0.4551 2.4947],     f(w): 8.3703
#      d(w):  [0.4791 3.24  ],     s.d:  [1.7517 2.11  ],     g(w): [0.6827 1.9829]
#
# 24. UCB suggests with (1 - Pr) =  0.2990476868768902
#    UCB create new index  23
#     w:  [3.2497 6.    ],     f(w): 13.4482
#      d(w):  [ 0.6948 -1.2071],     s.d:  [2.584 2.994],     g(w): [5.6979 0.9475]
#
# 25. GD suggests with Pr =  0.7260092826369012
#    GD (i, loop)  (20, 7)
#     w:  [0.0095 0.468 ],     f(w): 2.9902
#      d(w):  [-0.1376  2.9046],     s.d:  [0.0414 0.0245],     g(w): [0.2418 3.2796]
#
# 26. GD suggests with Pr =  1.0
#    GD (i, loop)  (20, 18)
#   # Optimal (ls, var) =  (2.0, 69.06625445401555)
#     w:  [0.0109 0.4293],     f(w): 2.8484
#      d(w):  [-0.2613  3.9409],     s.d:  [0.0775 0.0114],     g(w): [0.2924 4.0757]
#
# 27. GD suggests with Pr =  1.0
#    GD (i, loop)  (20, 219)
#     w:  [ 0.7351 -1.2409],     f(w): 5.4266
#      d(w):  [  9.7072 -12.2998],     s.d:  [0.8978 0.9666],     g(w): [-1.896  -5.0645]
#
# 28. UCB suggests with (1 - Pr) =  1
#    UCB create new index  24
#     w:  [ 3.1488 -6.    ],     f(w): 12.8286
#      d(w):  [ 6.5334 -3.6469],     s.d:  [2.3558 3.5612],     g(w): [ 6.1123 -0.9606]
#
# 29. UCB suggests with (1 - Pr) =  1
#    UCB create new index  25
#   # Optimal (ls, var) =  (2.0, 74.17267826271927)
#     w:  [4.0033 2.014 ],     f(w): 9.3936
#      d(w):  [ 4.8613 -0.5513],     s.d:  [1.6547 2.0277],     g(w): [1.5171 1.4215]
#
# 30. UCB suggests with (1 - Pr) =  1
#    UCB create new index  26
#     w:  [ 4.0945 -1.152 ],     f(w): 9.7388
#      d(w):  [5.1489 2.978 ],     s.d:  [1.5037 1.8574],     g(w): [ 5.0437 -5.6006]
#
# 31. UCB suggests with (1 - Pr) =  1
#    UCB create new index  27
#     w:  [ 3.7411 -3.7949],     f(w): 12.1874
#      d(w):  [ 3.9604 -4.7136],     s.d:  [1.9371 1.6831],     g(w): [-2.5712  2.4245]
#
# 32. UCB suggests with (1 - Pr) =  1
#    UCB create new index  28
#   # Optimal (ls, var) =  (2.0, 49.59112918210006)
#     w:  [-4.123  -0.8717],     f(w): 9.6759
#      d(w):  [-6.045  -1.3231],     s.d:  [1.1691 1.3769],     g(w): [-5.9595  4.2624]
#
# 33. UCB suggests with (1 - Pr) =  1
#    UCB create new index  29
#     w:  [-1.3057 -0.9743],     f(w): 5.4541
#      d(w):  [-10.9317  -1.7792],     s.d:  [0.5466 0.5546],     g(w): [-5.8724 -0.6477]
#
# 34. GD suggests with Pr =  1.0
#    GD (i, loop)  (29, 218)
#     w:  [-0.2428 -0.7799],     f(w): 3.7773
#      d(w):  [-3.2085 -4.5781],     s.d:  [0.1744 0.092 ],     g(w): [-4.2729  1.0595]
#
# 35. GD suggests with Pr =  0.9999999999171754
#    GD (i, loop)  (26, 137)
#   # Optimal (ls, var) =  (1.817018321049912, 89.76268646550102)
#     w:  [ 2.8165 -0.6517],     f(w): 8.5128
#      d(w):  [ 5.2135 -2.4747],     s.d:  [1.2667 1.1576],     g(w): [-0.8023  1.9257]
#
# 36. UCB suggests with (1 - Pr) =  1
#    UCB create new index  30
#     w:  [-1.6374 -3.6944],     f(w): 10.8156
#      d(w):  [ -5.301 -21.169],     s.d:  [2.9927 1.9546],     g(w): [0.8071 0.3376]
#
# 37. UCB suggests with (1 - Pr) =  1
#    UCB create new index  31
#     w:  [-2.2807 -2.0869],     f(w): 8.4079
#      d(w):  [-5.53   -7.7274],     s.d:  [0.9509 1.2247],     g(w): [-5.6439 -3.5051]
#
# 38. GD suggests with Pr =  0.9916360099704546
#    GD (i, loop)  (30, 200)
#   # Optimal (ls, var) =  (1.7385739104588684, 64.1056748385454)
#     w:  [-1.1014 -3.5209],     f(w): 9.9378
#      d(w):  [  2.5018 -11.6258],     s.d:  [0.8583 1.3129],     g(w): [-2.2022 -1.2267]
#
# 39. UCB suggests with (1 - Pr) =  1
#    UCB create new index  32
#     w:  [-4.0987 -4.7273],     f(w): 13.0634
#      d(w):  [-3.4624 -6.6335],     s.d:  [2.4272 2.4937],     g(w): [-3.3193  3.4695]
#
# 40. UCB suggests with (1 - Pr) =  1
#    UCB create new index  33
#     w:  [-0.6129  2.3739],     f(w): 8.0966
#      d(w):  [-4.6243 20.5531],     s.d:  [0.5529 1.2283],     g(w): [0.486  3.0138]
#
# 41. GD suggests with Pr =  0.9892756047660487
#    GD (i, loop)  (33, 83)
#   # Optimal (ls, var) =  (1.6217227015876068, 91.39183239068495)
#     w:  [-0.5365  1.9715],     f(w): 6.7323
#      d(w):  [-8.7505  1.0493],     s.d:  [0.7311 0.3162],     g(w): [0.161  1.4826]
# 42. UCB suggests with (1 - Pr) =  1
#    UCB create new index  34
#     w:  [-3.1927  3.3237],     f(w): 11.3421
#      d(w):  [-20.4723  12.5853],     s.d:  [3.5244 4.1789],     g(w): [-3.8255  3.7436]
#
# 43. GD suggests with Pr =  0.9077351857399245
#    GD (i, loop)  (34, 99)
#     w:  [-2.7752  3.0888],     f(w): 9.9474
#      d(w):  [-1.8196  6.7214],     s.d:  [2.1769 3.5621],     g(w): [4.0793 3.9189]
#
# 44. UCB suggests with (1 - Pr) =  1
#    UCB create new index  35
#   # Optimal (ls, var) =  (1.5455346282781963, 69.35869290325104)
#     w:  [2.714  1.9712],     f(w): 8.8108
#      d(w):  [-5.8502 10.3155],     s.d:  [1.7311 1.6016],     g(w): [-3.0523  0.2088]
#
# 45. GD suggests with Pr =  0.9999338150193556
#    GD (i, loop)  (35, 236)
#     w:  [3.342  0.9851],     f(w): 9.2471
#      d(w):  [ 7.4406 -1.3885],     s.d:  [1.2919 1.221 ],     g(w): [4.9524 0.1207]
#
# 46. UCB suggests with (1 - Pr) =  1
#    UCB create new index  36
#     w:  [4.3288 4.025 ],     f(w): 12.7566
#      d(w):  [5.1698 5.6795],     s.d:  [2.9006 2.8542],     g(w): [4.4702 1.4688]
#
# 47. UCB suggests with (1 - Pr) =  1
#    UCB create new index  37
#   # Optimal (ls, var) =  (1.5491716038837056, 71.68939857352679)
#     w:  [-1.001   4.6811],     f(w): 11.2186
#      d(w):  [-1.6877  5.6574],     s.d:  [3.3892 2.5731],     g(w): [-0.3263 -2.4057]
#
# 48. UCB suggests with (1 - Pr) =  1
#    UCB create new index  38
#     w:  [-3.7603  1.5233],     f(w): 10.8205
#      d(w):  [-8.1392  1.5424],     s.d:  [2.8641 2.6853],     g(w): [0.4975 0.3095]
#
# 49. UCB suggests with (1 - Pr) =  1
#    UCB create new index  39
#     w:  [-4.6883  4.713 ],     f(w): 14.1690
#      d(w):  [-4.1084  5.9356],     s.d:  [3.0536 2.9896],     g(w): [ 1.367  -1.4726]
#
# 50. UCB suggests with (1 - Pr) =  1
#    UCB create new index  40
#   # Optimal (ls, var) =  (1.578352512060362, 98.57046873713816)
#     w:  [ 5.3963 -1.7224],     f(w): 13.1251
#      d(w):  [8.7142 0.9068],     s.d:  [2.7579 2.6171],     g(w): [2.3835 1.5212]
#
# 51. UCB suggests with (1 - Pr) =  1
#    UCB create new index  41
#     w:  [-5.3197 -1.7423],     f(w): 12.8666
#      d(w):  [-7.4322  3.4255],     s.d:  [2.58   2.1624],     g(w): [-3.4646  2.0789]
#
# 52. UCB suggests with (1 - Pr) =  1
#    UCB create new index  42
#     w:  [ 2.1147 -3.6725],     f(w): 10.5825
#      d(w):  [-3.7773 -0.6207],     s.d:  [3.1175 2.1103],     g(w): [3.1642 1.8523]
#
# 53. UCB suggests with (1 - Pr) =  1
#    UCB create new index  43
#   # Optimal (ls, var) =  (1.5331038627236016, 66.29948451347884)
#     w:  [-4.766  -3.3951],     f(w): 13.2677
#      d(w):  [-4.9431 -4.6546],     s.d:  [1.7244 1.7901],     g(w): [ 1.2065 -2.0794]
#
# 54. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  44
#     w:  [-1.2948 -2.5175],     f(w): 8.7872
#      d(w):  [-6.1802 -5.0087],     s.d:  [0.563  0.7399],     g(w): [-2.4648 -1.5029]
#
# 55. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  45
#     w:  [-2.5935 -4.7738],     f(w): 12.7318
#      d(w):  [-5.8236 -6.2677],     s.d:  [1.7233 1.7388],     g(w): [0.6111 1.0548]
#
# 56. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  46
#   # Optimal (ls, var) =  (1.4767233349494349, 49.49855824620085)
#     w:  [-0.2713 -6.    ],     f(w): 12.6225
#      d(w):  [2.7343 3.0677],     s.d:  [2.5908 3.7805],     g(w): [-4.8566 -1.2084]
#
# 57. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  47
#     w:  [-2.6891 -1.035 ],     f(w): 8.0604
#      d(w):  [-4.8589 -0.1415],     s.d:  [0.7236 0.6379],     g(w): [ 2.1828 -1.6031]
#
# 58. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  48
#     w:  [ 0.5836 -3.2589],     f(w): 9.5649
#      d(w):  [ 3.6655 -0.8679],     s.d:  [1.1562 2.0124],     g(w): [-0.6818 -3.7222]
#
# 59. UCB suggests with (1 - Pr) =  1
#    UCB create new index  49
#   # Optimal (ls, var) =  (1.532203076660221, 92.14501338422508)
#     w:  [ 3.9885 -2.4395],     f(w): 11.3588
#      d(w):  [ 4.2316 -2.9111],     s.d:  [1.9761 1.4539],     g(w): [ 1.0113 -1.9674]
#
# 60. UCB suggests with (1 - Pr) =  1
#    UCB create new index  50
#     w:  [ 6.    -4.463],     f(w): 14.7585
#      d(w):  [-5.846  -3.4414],     s.d:  [5.0457 1.9255],     g(w): [ 0.7882 -1.3199]
#
# 61. UCB suggests with (1 - Pr) =  1
#    UCB create new index  51
#     w:  [1.9653 5.274 ],     f(w): 12.1839
#      d(w):  [-3.041  -0.5047],     s.d:  [2.8623 3.2426],     g(w): [-0.5803  5.89  ]
#
# 62. UCB suggests with (1 - Pr) =  1
#    UCB create new index  52
#   # Optimal (ls, var) =  (1.4897533265893421, 64.49498023448814)
#     w:  [-6.     -4.5531],     f(w): 14.7971
#      d(w):  [-0.2013 -1.4545],     s.d:  [3.2009 1.6987],     g(w): [-0.7766  0.4674]
#
# 63. UCB suggests with (1 - Pr) =  1
#    UCB create new index  53
#     w:  [-1.1038 -4.9499],     f(w): 10.5625
#      d(w):  [ 2.3697 -3.474 ],     s.d:  [1.7644 1.0894],     g(w): [-4.8644  0.9815]
#
# 64. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  54
#     w:  [6.     1.4341],     f(w): 13.3164
#      d(w):  [ 0.8005 -0.8612],     s.d:  [3.9847 1.5562],     g(w): [1.1497 1.5931]
#
# 65. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  55
#   # Optimal (ls, var) =  (1.5464650946493386, 89.38267358589849)
#     w:  [-4.3649 -6.    ],     f(w): 14.5299
#      d(w):  [3.1268 3.3235],     s.d:  [2.7587 2.7166],     g(w): [-3.376  -0.8009]
#
# 66. UCB suggests with (1 - Pr) =  1
#    UCB create new index  56
#     w:  [-2.7586  1.5013],     f(w): 9.2679
#      d(w):  [-0.3806  2.2561],     s.d:  [0.8248 1.1466],     g(w): [0.3613 0.8509]
#
# 67. UCB suggests with (1 - Pr) =  1
#    UCB create new index  57
#     w:  [-4.6359  0.2931],     f(w): 11.7195
#      d(w):  [-6.5102  4.977 ],     s.d:  [1.7296 1.5937],     g(w): [0.0282 1.9992]
#
# 68. UCB suggests with (1 - Pr) =  0.9999999999999999
#    UCB create new index  58
#   # Optimal (ls, var) =  (1.4859747094301154, 63.67492474552534)
#     w:  [-4.768   3.1995],     f(w): 12.6028
#      d(w):  [-2.8429 -0.2225],     s.d:  [1.2752 2.2397],     g(w): [2.8169 4.3903]
#
# 69. UCB suggests with (1 - Pr) =  1
#    UCB create new index  59
#     w:  [-1.7103  3.669 ],     f(w): 10.7430
#      d(w):  [-4.2085  8.1864],     s.d:  [1.2241 0.9477],     g(w): [ 1.4349 -0.4546]
#
# 70. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  60
#     w:  [ 0.7146 -0.4963],     f(w): 4.4905
#      d(w):  [6.9257 1.4295],     s.d:  [0.5696 0.2541],     g(w): [ 0.3897 -1.4662]
#
# 71. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  61
#   # Optimal (ls, var) =  (1.4051854520665257, 61.75373898679627)
#     w:  [-1.069  6.   ],     f(w): 11.6758
#      d(w):  [-2.1952 -0.8086],     s.d:  [2.3689 2.783 ],     g(w): [-3.6365  1.1761]
#
# 72. UCB suggests with (1 - Pr) =  0.8906850578197535
#    UCB create new index  62
#     w:  [4.6728 2.8069],     f(w): 12.5229
#      d(w):  [5.8955 4.3408],     s.d:  [2.1101 1.6072],     g(w): [-1.4998 -2.1026]
#
# 73. GD suggests with Pr =  1.0
#    GD (i, loop)  (60, 65)
#     w:  [ 0.0521 -0.2907],     f(w): 2.1219
#      d(w):  [ 4.9717 -3.3958],     s.d:  [0.2949 0.0918],     g(w): [ 1.906  -6.9697]
#
# 74. UCB suggests with (1 - Pr) =  1
#    UCB create new index  63
#   # Optimal (ls, var) =  (1.342859632001165, 69.59880465753643)
#     w:  [ 1.7487 -1.1071],     f(w): 6.3208
#      d(w):  [ 7.2048 -7.048 ],     s.d:  [0.6533 1.01  ],     g(w): [-2.843  -4.0125]
#
# 75. UCB suggests with (1 - Pr) =  0.9987292809946371
#    UCB create new index  64
#     w:  [ 0.8505 -2.3599],     f(w): 7.7146
#      d(w):  [ 6.3169 -4.4758],     s.d:  [1.8954 0.506 ],     g(w): [-1.8048 -4.2315]
#
# 76. UCB suggests with (1 - Pr) =  0.9999999999992998
#    UCB create new index  65
#     w:  [-6.     1.571],     f(w): 13.3486
#      d(w):  [ 6.6043 -1.0364],     s.d:  [4.3893 2.3819],     g(w): [-1.1382 -1.1262]
#
# 77. UCB suggests with (1 - Pr) =  1
#    UCB create new index  66
#   # Optimal (ls, var) =  (1.3810390921694407, 96.53077255621422)
#     w:  [-3.5373  0.1537],     f(w): 9.7793
#      d(w):  [-4.9199  2.7886],     s.d:  [0.6764 1.2994],     g(w): [-1.116  2.186]
#
# 78. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  67
#     w:  [0.3662 1.7793],     f(w): 6.4644
#      d(w):  [14.1662 -1.3967],     s.d:  [1.0876 0.4219],     g(w): [ 2.2787 -0.282 ]
#
# 79. UCB suggests with (1 - Pr) =  1
#    UCB create new index  68
#     w:  [0.8696 4.415 ],     f(w): 11.2191
#      d(w):  [-1.241   0.8723],     s.d:  [2.6762 2.2754],     g(w): [-1.8105  2.9324]
#
# 80. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  69
#   # Optimal (ls, var) =  (1.354499412751153, 68.5413586103438)
#     w:  [ 0.1803 -4.7142],     f(w): 11.3494
#      d(w):  [ 2.1381 -3.7614],     s.d:  [1.5251 1.5474],     g(w): [3.2012 1.9358]
#
# 81. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  70
#     w:  [6.     4.4878],     f(w): 14.7851
#      d(w):  [-2.901   0.4847],     s.d:  [4.5546 2.7193],     g(w): [0.785 0.829]
#
# 82. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  71
#     w:  [-3.3186  4.8041],     f(w): 13.0014
#      d(w):  [2.6815 2.6363],     s.d:  [2.7116 2.0237],     g(w): [-3.4402 -1.8203]
#
# 83. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  72
#   # Optimal (ls, var) =  (1.3884117622950565, 95.6247054295989)
#     w:  [ 4.5943 -6.    ],     f(w): 14.7603
#      d(w):  [0.6066 3.3584],     s.d:  [2.5573 5.519 ],     g(w): [-1.3202 -0.7713]
#
# 84. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  73
#     w:  [ 3.0451 -3.0658],     f(w): 9.3084
#      d(w):  [ 1.4246 -2.5405],     s.d:  [0.9661 0.9212],     g(w): [ 3.3258 -4.3136]
#
# 85. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  74
#     w:  [ 3.0586 -4.8055],     f(w): 11.8903
#      d(w):  [ 0.0904 -2.0225],     s.d:  [2.1861 1.656 ],     g(w): [2.8167 4.5183]
#
# 86. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  75
#   # Optimal (ls, var) =  (1.3375675645573732, 55.41480370497248)
#     w:  [-6.      4.4676],     f(w): 14.7644
#      d(w):  [5.6265 1.6873],     s.d:  [2.9534 2.2878],     g(w): [-0.7876  1.2274]
#
# 87. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  76
#     w:  [-0.1535 -0.1254],     f(w): 1.3787
#      d(w):  [ 0.6271 -0.0034],     s.d:  [0.0935 0.0331],     g(w): [-7.0142 -5.953 ]
#
# 88. GD suggests with Pr =  0.9999999835754734
#    GD (i, loop)  (76, 4)
#     w:  [-0.1634 -0.1252],     f(w): 1.4480
#      d(w):  [-7.2279  2.2101],     s.d:  [0.0148 0.0228],     g(w): [-7.1366 -5.7733]
#
# 89. GD suggests with Pr =  1.0
#    GD (i, loop)  (76, 51)
#   # Optimal (ls, var) =  (0.7167435207943722, 94.63152164062416)
#     w:  [-0.0752 -0.1349],     f(w): 0.9776
#      d(w):  [-3.513  -1.2996],     s.d:  [0.2122 0.7698],     g(w): [-4.4535 -7.5358]
#
# 90. UCB suggests with (1 - Pr) =  1
#    UCB create new index  77
#     w:  [4.5485 0.3479],     f(w): 11.7613
#      d(w):  [ 1.7177 -0.3007],     s.d:  [12.5912 13.018 ],     g(w): [1.0413 1.3066]
#
# 91. UCB suggests with (1 - Pr) =  1
#    UCB create new index  78
#     w:  [4.6125 6.    ],     f(w): 14.7327
#      d(w):  [ 0.3617 -1.392 ],     s.d:  [12.2367 13.5419],     g(w): [-1.7094  0.7689]
#
# 92. UCB suggests with (1 - Pr) =  1
#    UCB create new index  79
#   # Optimal (ls, var) =  (0.7233659934256395, 96.97940223540326)
#     w:  [1.4934 1.6728],     f(w): 7.6729
#      d(w):  [3.3105 0.884 ],     s.d:  [10.1176 12.3635],     g(w): [1.4344 0.2007]
#
# 93. UCB suggests with (1 - Pr) =  1
#    UCB create new index  80
#     w:  [-4.3353  6.    ],     f(w): 14.4204
#      d(w):  [ 0.2722 -5.1961],     s.d:  [13.0295 12.7379],     g(w): [-4.0303  0.8048]
#
# 94. UCB suggests with (1 - Pr) =  1
#    UCB create new index  81
#     w:  [-1.4635  0.988 ],     f(w): 6.1262
#      d(w):  [-7.0614 -4.475 ],     s.d:  [10.3547 10.4708],     g(w): [-2.5486  0.9938]
#
# 95. UCB suggests with (1 - Pr) =  1
#    UCB create new index  82
#   # Optimal (ls, var) =  (0.7170735104723129, 73.8039231640092)
#     w:  [1.458  0.0783],     f(w): 5.4907
#      d(w):  [8.101  9.4227],     s.d:  [7.3819 8.4893],     g(w): [3.083 1.546]
#
# 96. UCB suggests with (1 - Pr) =  1
#    UCB create new index  83
#     w:  [-3.0115 -3.5202],     f(w): 11.3282
#      d(w):  [-1.0761 -0.8081],     s.d:  [10.5842 10.4221],     g(w): [-1.1814 -0.7171]
#
# 97. UCB suggests with (1 - Pr) =  1
#    UCB create new index  84
#     w:  [ 4.6805 -4.5733],     f(w): 14.2740
#      d(w):  [ 1.2883 -1.7621],     s.d:  [10.5119 10.9831],     g(w): [-0.6704 -0.0617]
#
# 98. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  85
#   # Optimal (ls, var) =  (0.732015817881397, 97.34929669346978)
#     w:  [-0.1974  3.7045],     f(w): 9.8613
#      d(w):  [0.1239 0.8241],     s.d:  [11.4793 10.8027],     g(w): [-3.1243 -1.4074]
#
# 99. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  86
#     w:  [3.2729 4.7082],     f(w): 13.0116
#      d(w):  [-0.4148  0.8199],     s.d:  [11.8257 11.4705],     g(w): [ 3.2596 -1.4483]
#
# 100. UCB suggests with (1 - Pr) =  1
#    UCB create new index  87
#     w:  [ 1.0983 -6.    ],     f(w): 11.7986
#      d(w):  [-1.9765  5.9764],     s.d:  [12.1238 11.5184],     g(w): [ 4.7226 -1.1742]
#
# 101. UCB suggests with (1 - Pr) =  1
#    UCB create new index  88
#   # Optimal (ls, var) =  (0.7168340343687977, 55.41117010097361)
#     w:  [1.5284 3.0589],     f(w): 9.4125
#      d(w):  [0.8388 1.0351],     s.d:  [8.352  9.1938],     g(w): [0.2365 2.667 ]
#
# 102. UCB suggests with (1 - Pr) =  1
#    UCB create new index  89
#     w:  [-4.812   1.9095],     f(w): 11.2581
#      d(w):  [-2.3725  0.6173],     s.d:  [8.2668 9.2656],     g(w): [ 4.0912 -2.6144]
#
# 103. UCB suggests with (1 - Pr) =  1
#    UCB create new index  90
#     w:  [-2.132   4.8421],     f(w): 11.4115
#      d(w):  [-0.6349  1.1447],     s.d:  [8.0406 8.9751],     g(w): [-4.8083 -3.6211]
#
# 104. UCB suggests with (1 - Pr) =  1
#    UCB create new index  91
#   # Optimal (ls, var) =  (0.7367213967043204, 91.59811433485561)
#     w:  [3.4467 2.9703],     f(w): 11.1896
#      d(w):  [1.2351 2.2049],     s.d:  [9.7665 9.913 ],     g(w): [2.1792 0.3768]
#
# 105. UCB suggests with (1 - Pr) =  1
#    UCB create new index  92
#     w:  [-6.     -1.0392],     f(w): 11.5873
#      d(w):  [5.0347 0.3097],     s.d:  [11.6858  9.9331],     g(w): [-1.178  -2.2555]
#
# 106. UCB suggests with (1 - Pr) =  1
#    UCB create new index  93
#     w:  [ 4.8955 -3.2851],     f(w): 12.6983
#      d(w):  [ 1.1036 -0.7582],     s.d:  [ 9.9816 11.0126],     g(w): [-1.5339 -4.7668]
#
# 107. UCB suggests with (1 - Pr) =  1
#    UCB create new index  94
#   # Optimal (ls, var) =  (0.743993210646005, 99.42860785123969)
#     w:  [4.8755 1.4782],     f(w): 12.1193
#      d(w):  [ 3.3549 -0.8446],     s.d:  [ 9.4615 10.6317],     g(w): [-0.6073  0.7717]
#
# 108. UCB suggests with (1 - Pr) =  1
#    UCB create new index  95
#     w:  [-3.2047 -6.    ],     f(w): 13.1781
#      d(w):  [-1.1825  4.6863],     s.d:  [ 9.8615 12.5009],     g(w): [-6.23   -0.9534]
#
# 109. UCB suggests with (1 - Pr) =  1
#    UCB create new index  96
#     w:  [ 3.5489 -0.0982],     f(w): 9.6794
#      d(w):  [3.9997 2.1064],     s.d:  [8.7678 8.8765],     g(w): [ 0.8241 -1.7445]
#
# 110. UCB suggests with (1 - Pr) =  1
#    UCB create new index  97
#   # Optimal (ls, var) =  (0.7383039206380206, 80.45705298695233)
#     w:  [1.7016 6.    ],     f(w): 13.0196
#      d(w):  [-1.9434 -4.2323],     s.d:  [10.158   8.5852],     g(w): [-3.9357  1.1264]
#
# 111. UCB suggests with (1 - Pr) =  1
#    UCB create new index  98
#     w:  [-3.6988  2.4844],     f(w): 11.5488
#      d(w):  [-1.0266  0.8424],     s.d:  [9.191  7.3983],     g(w): [0.2964 0.999 ]
#
# 112. UCB suggests with (1 - Pr) =  1
#    UCB create new index  99
#     w:  [-0.044   5.0221],     f(w): 10.2336
#      d(w):  [1.0921 1.662 ],     s.d:  [8.355  9.1683],     g(w): [-2.2889  2.543 ]
#
# 113. UCB suggests with (1 - Pr) =  1
#    UCB create new index  100
#   # Optimal (ls, var) =  (0.7494855723422447, 98.01272279051744)
#     w:  [4.8542 4.9289],     f(w): 13.0709
#      d(w):  [1.9627 1.9557],     s.d:  [10.9799  9.2952],     g(w): [-4.5575 -2.131 ]
#
# 114. UCB suggests with (1 - Pr) =  1
#    UCB create new index  101
#     w:  [ 1.1025 -4.1087],     f(w): 9.5613
#      d(w):  [ 1.4606 -1.9955],     s.d:  [8.7093 8.5644],     g(w): [ 4.548  -5.8553]
#
# 115. UCB suggests with (1 - Pr) =  1
#    UCB create new index  102
#     w:  [ 5.0531 -0.6522],     f(w): 11.7864
#      d(w):  [ 1.3546 -0.1823],     s.d:  [9.2409 9.0397],     g(w): [2.6016 2.9093]
#
# 116. UCB suggests with (1 - Pr) =  1
#    UCB create new index  103
#   # Optimal (ls, var) =  (0.736816354464617, 54.61833658638876)
#     w:  [-3.4401 -1.5992],     f(w): 10.6039
#      d(w):  [-0.9134 -2.0545],     s.d:  [6.936 6.082],     g(w): [-1.9831  0.0699]
#
# 117. UCB suggests with (1 - Pr) =  1
#    UCB create new index  104
#     w:  [ 1.2867 -1.6901],     f(w): 7.1656
#      d(w):  [ 13.8623 -11.2893],     s.d:  [4.2445 3.9863],     g(w): [3.5389 0.502 ]
# 118. UCB suggests with (1 - Pr) =  0.9944023742167548
#    UCB create new index  105
#     w:  [-0.7745  1.1797],     f(w): 4.9995
#      d(w):  [-7.1142  2.5218],     s.d:  [3.1722 3.4042],     g(w): [2.8797 5.7342]
#
# 119. UCB suggests with (1 - Pr) =  1
#    UCB create new index  106
#   # Optimal (ls, var) =  (0.7459993625316782, 87.05246562007619)
#     w:  [-0.1639 -2.7247],     f(w): 7.9280
#      d(w):  [-2.655  -0.0088],     s.d:  [7.1276 7.5702],     g(w): [-3.3339  1.7883]
#
# 120. UCB suggests with (1 - Pr) =  1
#    UCB create new index  107
#     w:  [ 2.1374 -6.    ],     f(w): 12.3113
#      d(w):  [0.5622 4.975 ],     s.d:  [ 7.8181 10.4694],     g(w): [ 5.8338 -1.0824]
#
# 121. UCB suggests with (1 - Pr) =  1
#    UCB create new index  108
#     w:  [1.8386 4.2046],     f(w): 10.7675
#      d(w):  [0.0302 0.0768],     s.d:  [7.7054 7.8484],     g(w): [-3.4067  5.8737]
#
# 122. UCB suggests with (1 - Pr) =  1
#    UCB create new index  109
#   # Optimal (ls, var) =  (0.7507460958933801, 92.63853919982633)
#     w:  [-5.0777 -5.0535],     f(w): 12.9632
#      d(w):  [-1.7231 -1.4489],     s.d:  [ 8.3731 10.2713],     g(w): [-4.4002 -3.3097]
#
# 123. UCB suggests with (1 - Pr) =  1
#    UCB create new index  110
#     w:  [-2.2381 -2.9141],     f(w): 9.2294
#      d(w):  [-2.9713 -2.9574],     s.d:  [7.7935 6.1002],     g(w): [-6.0187  1.2396]
#
# 124. UCB suggests with (1 - Pr) =  1
#    UCB create new index  111
#     w:  [-5.0907 -0.6514],     f(w): 11.8999
#      d(w):  [-2.7108  0.344 ],     s.d:  [7.2478 8.3713],     g(w): [-3.289   2.7412]
#
# 125. UCB suggests with (1 - Pr) =  1
#    UCB create new index  112
#   # Optimal (ls, var) =  (0.7388335948590922, 61.04243667782396)
#     w:  [ 3.2839 -1.5748],     f(w): 10.1929
#      d(w):  [ 0.8907 -0.378 ],     s.d:  [5.9714 6.562 ],     g(w): [3.2926 0.089 ]
#
# 126. UCB suggests with (1 - Pr) =  1
#    UCB create new index  113
#     w:  [ 1.4134 -0.5948],     f(w): 6.1866
#      d(w):  [14.2009  3.181 ],     s.d:  [3.1712 3.2001],     g(w): [ 2.7993 -0.1234]
#
# 127. UCB suggests with (1 - Pr) =  1
#    UCB create new index  114
#     w:  [-2.2553  0.7437],     f(w): 7.4594
#      d(w):  [-4.824  -0.9469],     s.d:  [5.3992 6.2265],     g(w): [-4.947  -2.3933]
#
# 128. UCB suggests with (1 - Pr) =  1
#    UCB create new index  115
#   # Optimal (ls, var) =  (0.7094143419944562, 46.116115958104594)
#     w:  [1.3486 0.8953],     f(w): 5.6992
#      d(w):  [0.1607 3.3872],     s.d:  [5.9212 3.7355],     g(w): [ 4.7172 -0.8895]
#
# 129. UCB suggests with (1 - Pr) =  1
#    UCB create new index  116
#     w:  [ 1.7521 -2.8689],     f(w): 8.8716
#      d(w):  [-0.6549  1.9976],     s.d:  [6.6578 6.1554],     g(w): [-3.5254  1.7582]
#
# 130. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  117
#     w:  [-0.2074 -3.8704],     f(w): 9.5494
#      d(w):  [ 0.7837 -1.7144],     s.d:  [5.9298 6.1348],     g(w): [-4.9608  2.043 ]
#
# 131. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  118
#   # Optimal (ls, var) =  (0.7218438556977763, 67.4683654909817)
#     w:  [-1.9665 -0.1967],     f(w): 5.6730
#      d(w):  [ 6.171  -0.3427],     s.d:  [5.9848 6.882 ],     g(w): [-0.8662 -5.9152]
#
# 132. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  119
#     w:  [-4.4238 -1.9517],     f(w): 11.5903
#      d(w):  [-0.7444 -0.9732],     s.d:  [6.3019 8.3904],     g(w): [-2.8031  0.394 ]
#
# 133. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  120
#     w:  [5.3548 3.6696],     f(w): 14.1541
#      d(w):  [0.8801 0.8246],     s.d:  [8.1292 7.9089],     g(w): [ 2.3681 -0.9506]
#
# 134. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  121
#   # Optimal (ls, var) =  (0.7292556019594238, 75.99960486568456)
#     w:  [ 6.     -1.1625],     f(w): 12.1505
#      d(w):  [-6.1856  0.8571],     s.d:  [8.8134 8.3145],     g(w): [ 1.17   -5.9616]
#
# 135. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  122
#     w:  [ 0.2319 -1.8866],     f(w): 5.8875
#      d(w):  [-4.891  -0.2195],     s.d:  [4.3339 4.8896],     g(w): [5.0866 1.0273]
#
# 136. UCB suggests with (1 - Pr) =  1
#    UCB create new index  123
#     w:  [-1.1831 -6.    ],     f(w): 12.2743
#      d(w):  [1.1115 3.5342],     s.d:  [6.2588 9.9385],     g(w): [-6.0295 -1.1686]
#
# 137. UCB suggests with (1 - Pr) =  1
#    UCB create new index  124
#   # Optimal (ls, var) =  (0.7295184892250239, 73.98532703332542)
#     w:  [-4.0557  3.966 ],     f(w): 11.1443
#      d(w):  [-0.9046  0.8971],     s.d:  [7.4702 7.5221],     g(w): [-3.7143 -0.8516]
#
# 138. UCB suggests with (1 - Pr) =  1
#    UCB create new index  125
#     w:  [-5.2317  0.9832],     f(w): 11.5567
#      d(w):  [-2.1578  0.0961],     s.d:  [7.8847 7.1606],     g(w): [-6.7428 -0.3315]
#
# 139. UCB suggests with (1 - Pr) =  1
#    UCB create new index  126
#     w:  [2.2065 2.5858],     f(w): 9.6065
#      d(w):  [1.3422 2.0379],     s.d:  [6.8258 6.4671],     g(w): [3.3895 0.1279]
#
# 140. UCB suggests with (1 - Pr) =  1
#    UCB create new index  127
#   # Optimal (ls, var) =  (0.7452541366158453, 97.33048401386652)
#     w:  [-2.6153  4.0388],     f(w): 11.4735
#      d(w):  [-0.8905  0.7568],     s.d:  [7.4003 6.9077],     g(w): [1.5475 2.0488]
#
# 141. UCB suggests with (1 - Pr) =  1
#    UCB create new index  128
#     w:  [ 3.9006 -5.188 ],     f(w): 12.9177
#      d(w):  [ 1.7572 -1.7086],     s.d:  [7.6448 8.7752],     g(w): [-2.6526 -6.1746]
#
# 142. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  129
#     w:  [-3.8977 -3.7539],     f(w): 11.9040
#      d(w):  [-1.2327 -0.1519],     s.d:  [7.4339 8.6154],     g(w): [1.8962 3.8307]
#
# 143. UCB suggests with (1 - Pr) =  1
#    UCB create new index  130
#   # Optimal (ls, var) =  (0.7480672061814588, 97.42193532146642)
#     w:  [-1.8824  6.    ],     f(w): 12.1133
#      d(w):  [-1.0507 -3.546 ],     s.d:  [ 5.9452 11.3397],     g(w): [4.6991 1.109 ]
#
# 144. UCB suggests with (1 - Pr) =  1
#    UCB create new index  131
#     w:  [0.7087 3.534 ],     f(w): 10.1655
#      d(w):  [-0.2809 -0.022 ],     s.d:  [6.7185 6.5676],     g(w): [-1.3045  1.3066]
#
# 145. UCB suggests with (1 - Pr) =  1
#    UCB create new index  132
#     w:  [3.9998 5.21  ],     f(w): 12.9517
#      d(w):  [-0.8417  2.6225],     s.d:  [6.7579 8.1254],     g(w): [0.6722 6.567 ]
#
# 146. UCB suggests with (1 - Pr) =  1
#    UCB create new index  133
#   # Optimal (ls, var) =  (0.7306674176056773, 64.73153371915522)
#     w:  [5.4747 0.6235],     f(w): 13.1161
#      d(w):  [-0.2588  1.2732],     s.d:  [6.6882 6.3594],     g(w): [ 1.5017 -0.7929]
#
# 147. UCB suggests with (1 - Pr) =  1
#    UCB create new index  134
#     w:  [-2.4371  2.2643],     f(w): 9.6213
#      d(w):  [-1.9765  0.5614],     s.d:  [6.1415 5.1275],     g(w): [-2.0234  3.0883]
#
# 148. UCB suggests with (1 - Pr) =  1
#    UCB create new index  135
#     w:  [-1.6762  2.8634],     f(w): 9.0998
#      d(w):  [1.3371 1.59  ],     s.d:  [6.6388 4.1934],     g(w): [ 2.2214 -1.1089]
#
# 149. UCB suggests with (1 - Pr) =  1
#    UCB create new index  136
#   # Optimal (ls, var) =  (0.7182238185879178, 73.03783686901983)
#     w:  [-0.7597 -1.0524],     f(w): 4.4174
#      d(w):  [-8.9794 -4.9129],     s.d:  [1.9154 4.3965],     g(w): [ 3.8111 -3.5883]
#
# 150. UCB suggests with (1 - Pr) =  1
#    UCB create new index  137
#     w:  [-1.9646 -1.2402],     f(w): 6.6400
#      d(w):  [-2.9454 -8.2693],     s.d:  [4.3501 6.1789],     g(w): [-0.5593 -6.3526]
#
# 151. UCB suggests with (1 - Pr) =  1
#    UCB create new index  138
#     w:  [ 2.4945 -1.3704],     f(w): 8.9151
#      d(w):  [ 3.3984 -2.0069],     s.d:  [4.2147 4.5618],     g(w): [ 1.7039 -1.894 ]
#
# 152. UCB suggests with (1 - Pr) =  1
#    UCB create new index  139
#   # Optimal (ls, var) =  (0.6954168307220082, 37.85251697426057)
#     w:  [-5.0599 -4.1769],     f(w): 12.8237
#      d(w):  [-1.6027  0.5053],     s.d:  [6.4756 4.9161],     g(w): [-3.157  -6.3075]
#
# 153. UCB suggests with (1 - Pr) =  1
#    UCB create new index  140
#     w:  [0.8724 0.0967],     f(w): 2.9186
#      d(w):  [2.1676 7.3881],     s.d:  [1.4815 2.1772],     g(w): [-2.3353  4.1044]
#
# 154. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  141
#     w:  [-3.3223 -0.6035],     f(w): 9.7727
#      d(w):  [-3.0758 -0.2611],     s.d:  [3.5815 4.0952],     g(w): [-3.2488  0.712 ]
#
# 155. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  142
#   # Optimal (ls, var) =  (0.7317239028608066, 97.93859014585315)
#     w:  [-6.     -2.0209],     f(w): 11.8425
#      d(w):  [ 5.6873 -0.9944],     s.d:  [8.6688 7.3372],     g(w): [-1.0949 -1.4802]
# 156. UCB suggests with (1 - Pr) =  0.9999999999999789
#    UCB create new index  143
#     w:  [-5.3479  3.8335],     f(w): 13.8687
#      d(w):  [-1.5612  1.7827],     s.d:  [8.6113 8.156 ],     g(w): [-3.3773 -1.9679]
#
# 157. UCB suggests with (1 - Pr) =  0.9999999690911398
#    UCB create new index  144
#     w:  [-5.2204  5.5961],     f(w): 15.2151
#      d(w):  [-0.4273 -1.2077],     s.d:  [8.1736 9.8865],     g(w): [-2.8978 -0.5963]
#
# 158. UCB suggests with (1 - Pr) =  0.9999998597616
#    UCB create new index  145
#   # Optimal (ls, var) =  (0.7329845879927936, 96.67214589196774)
#     w:  [-1.7927 -4.6578],     f(w): 11.9759
#      d(w):  [-2.6504 -1.6277],     s.d:  [6.0345 8.6849],     g(w): [2.1286 0.9792]
#
# 159. UCB suggests with (1 - Pr) =  0.9999998050929216
#    UCB create new index  146
#     w:  [ 5.3648 -5.2764],     f(w): 15.1559
#      d(w):  [ 0.4289 -0.6961],     s.d:  [8.7849 8.3162],     g(w): [ 2.2579 -2.7355]
#
# 160. UCB suggests with (1 - Pr) =  1
#    UCB create new index  147
#     w:  [4.0904 1.1394],     f(w): 9.6479
#      d(w):  [ 3.1764 -1.8076],     s.d:  [5.5314 6.73  ],     g(w): [5.041  5.4831]
#
# 161. UCB suggests with (1 - Pr) =  1
#    UCB create new index  148
#   # Optimal (ls, var) =  (0.6963289948286961, 33.696989023076696)
#     w:  [1.0377 5.2669],     f(w): 11.8154
#      d(w):  [0.4672 3.4746],     s.d:  [5.2105 4.5294],     g(w): [1.3928 6.1152]
#
# 162. UCB suggests with (1 - Pr) =  1
#    UCB create new index  149
#     w:  [ 2.1906 -4.5097],     f(w): 12.1472
#      d(w):  [ 0.7191 -1.5077],     s.d:  [5.0225 4.7832],     g(w): [ 2.7393 -1.1133]
#
# 163. UCB suggests with (1 - Pr) =  1
#    UCB create new index  150
#     w:  [2.1172 1.3229],     f(w): 7.5066
#      d(w):  [2.7159 1.6875],     s.d:  [3.9941 3.6422],     g(w): [4.1353 4.3245]
#
# 164. UCB suggests with (1 - Pr) =  1
#    UCB create new index  151
#   # Optimal (ls, var) =  (0.7262944628199526, 86.09302898489743)
#     w:  [-1.8942 -0.6978],     f(w): 6.4234
#      d(w):  [-6.8852 -0.7247],     s.d:  [3.8363 1.9044],     g(w): [0.4503 3.0182]
#
# 165. UCB suggests with (1 - Pr) =  1
#    UCB create new index  152
#     w:  [ 4.8863 -2.4134],     f(w): 12.5134
#      d(w):  [ 1.199  -0.6157],     s.d:  [7.5325 7.0719],     g(w): [-0.7843 -2.1274]
#
# 166. UCB suggests with (1 - Pr) =  1
#    UCB create new index  153
#     w:  [ 2.9279 -3.9441],     f(w): 10.2265
#      d(w):  [ 0.0323 -1.1782],     s.d:  [5.3776 5.6074],     g(w): [-2.6038  1.5745]
#
# 167. UCB suggests with (1 - Pr) =  1
#    UCB create new index  154
#   # Optimal (ls, var) =  (0.6988070846775228, 39.85059138503798)
#     w:  [-0.8471 -4.2871],     f(w): 10.7515
#      d(w):  [-1.3253 -0.4671],     s.d:  [4.7614 3.5715],     g(w): [ 2.7592 -5.1221]
#
# 168. UCB suggests with (1 - Pr) =  1
#    UCB create new index  155
#     w:  [-3.2244  0.8465],     f(w): 8.7960
#      d(w):  [-0.5745  0.8612],     s.d:  [4.5332 3.3289],     g(w): [-6.1743 -3.2702]
#
# 169. UCB suggests with (1 - Pr) =  1
#    UCB create new index  156
#     w:  [-0.9432  3.4859],     f(w): 9.7460
#      d(w):  [-0.279  -0.7139],     s.d:  [3.7067 5.5366],     g(w): [0.6219 1.9083]
#
# 170. UCB suggests with (1 - Pr) =  1
#    UCB create new index  157
#   # Optimal (ls, var) =  (0.7352107303319728, 94.05375697816346)
#     w:  [-1.5741  0.3624],     f(w): 6.3402
#      d(w):  [ 9.1319 -1.8543],     s.d:  [4.1234 3.4717],     g(w): [-1.541   1.6106]
#
# 171. UCB suggests with (1 - Pr) =  1
#    UCB create new index  158
#     w:  [3.4497 3.8319],     f(w): 12.2769
#      d(w):  [0.1576 1.012 ],     s.d:  [6.6021 6.2806],     g(w): [ 1.6887 -1.1608]
#
# 172. UCB suggests with (1 - Pr) =  1
#    UCB create new index  159
#     w:  [-4.3461  1.0095],     f(w): 10.8371
#      d(w):  [-0.4818  0.0847],     s.d:  [5.7879 5.6956],     g(w): [-4.6723  0.5737]
#
# 173. UCB suggests with (1 - Pr) =  1
#    UCB create new index  160
#   # Optimal (ls, var) =  (0.7152861359656664, 58.371119683044945)
#     w:  [-5.0917 -2.5624],     f(w): 12.8283
#      d(w):  [-1.9657 -1.0405],     s.d:  [6.2928 4.8537],     g(w): [-2.7678  0.5824]
#
# 174. UCB suggests with (1 - Pr) =  1
#    UCB create new index  161
#     w:  [-2.9315 -2.5299],     f(w): 10.1878
#      d(w):  [-2.5081 -0.3665],     s.d:  [3.5307 5.4663],     g(w): [ 0.0256 -0.504 ]
#
# 175. UCB suggests with (1 - Pr) =  1
#    UCB create new index  162
#     w:  [ 6.     -2.0952],     f(w): 12.0848
#      d(w):  [-5.8265 -0.5431],     s.d:  [7.2803 5.1418],     g(w): [ 1.087  -4.7894]
#
# 176. UCB suggests with (1 - Pr) =  1
#    UCB create new index  163
#   # Optimal (ls, var) =  (0.7221267239605346, 65.94805613413266)
#     w:  [-5.1843 -6.    ],     f(w): 14.1871
#      d(w):  [-0.949   3.6304],     s.d:  [5.1816 8.3703],     g(w): [-6.4009 -0.6973]
#
# 177. UCB suggests with (1 - Pr) =  1
#    UCB create new index  164
#     w:  [-3.5387  6.    ],     f(w): 14.2355
#      d(w):  [-0.9941 -4.869 ],     s.d:  [4.3112 9.999 ],     g(w): [0.2318 0.9097]
#
# 178. UCB suggests with (1 - Pr) =  1
#    UCB create new index  165
#     w:  [-3.3194 -4.3925],     f(w): 12.9895
#      d(w):  [-0.213  -0.7632],     s.d:  [4.7422 6.207 ],     g(w): [-2.3435 -2.112 ]
#
# 179. UCB suggests with (1 - Pr) =  1
#    UCB create new index  166
#   # Optimal (ls, var) =  (0.7053499171184904, 40.037263756963334)
#     w:  [1.1549 2.3564],     f(w): 7.9470
#      d(w):  [1.0835 1.9967],     s.d:  [4.021  3.4554],     g(w): [3.3829 4.1489]
#
# 180. UCB suggests with (1 - Pr) =  1
#    UCB create new index  167
#     w:  [ 1.1809 -1.0854],     f(w): 4.8808
#      d(w):  [ 2.7715 -0.7461],     s.d:  [1.0392 1.358 ],     g(w): [ 7.0654 -4.5709]
#
# 181. UCB suggests with (1 - Pr) =  1
#    UCB create new index  168
#     w:  [-0.1499 -1.44  ],     f(w): 5.5781
#      d(w):  [1.9709 1.6464],     s.d:  [1.6107 1.5652],     g(w): [-2.3805 -3.2678]
#
# 182. UCB suggests with (1 - Pr) =  1
#    UCB create new index  169
#   # Optimal (ls, var) =  (0.730204713411242, 85.3486085728961)
#     w:  [-6.     -3.7128],     f(w): 13.8763
#      d(w):  [ 4.5978 -2.1431],     s.d:  [10.3285  4.9565],     g(w): [-0.8867  3.9395]
#
# 183. UCB suggests with (1 - Pr) =  1
#    UCB create new index  170
#     w:  [ 0.5779 -5.4079],     f(w): 13.0268
#      d(w):  [-0.5876 -1.4233],     s.d:  [6.8439 6.1761],     g(w): [-0.4855 -2.0308]
#
# 184. UCB suggests with (1 - Pr) =  1
#    UCB create new index  171
#     w:  [2.4873 6.    ],     f(w): 13.7347
#      d(w):  [ 0.5125 -3.9732],     s.d:  [4.7515 9.6336],     g(w): [0.6829 1.0428]
#
# 185. UCB suggests with (1 - Pr) =  1
#    UCB create new index  172
#   # Optimal (ls, var) =  (0.7063090426023938, 46.826155014870565)
#     w:  [5.3375 2.2285],     f(w): 13.0680
#      d(w):  [2.3738 0.3869],     s.d:  [5.5822 5.1901],     g(w): [3.3589 3.0456]
#
# 186. UCB suggests with (1 - Pr) =  1
#    UCB create new index  173
#     w:  [-0.2938  6.    ],     f(w): 12.7268
#      d(w):  [ 1.7204 -2.6612],     s.d:  [3.6998 7.9843],     g(w): [-4.411  1.208]
#
# 187. UCB suggests with (1 - Pr) =  1
#    UCB create new index  174
#     w:  [-1.4921 -1.8275],     f(w): 7.6253
#      d(w):  [ 1.5375 -1.5385],     s.d:  [3.149  2.7251],     g(w): [-1.4006  0.5598]
#
# 188. UCB suggests with (1 - Pr) =  1
#    UCB create new index  175
#   # Optimal (ls, var) =  (0.7166593377927875, 66.49415268470598)
#     w:  [-0.6227 -0.6379],     f(w): 4.5818
#      d(w):  [-13.024    5.8306],     s.d:  [1.1914 0.8814],     g(w): [-0.6356 -0.5743]
#
# 189. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  176
#     w:  [ 2.3498 -0.1588],     f(w): 7.4059
#      d(w):  [0.3003 0.19  ],     s.d:  [4.88   3.8546],     g(w): [ 4.5108 -2.7186]
#
# 190. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  177
#     w:  [ 4.3658 -1.7495],     f(w): 11.7184
#      d(w):  [ 3.6345 -1.5415],     s.d:  [5.7627 4.1991],     g(w): [3.0295 1.708 ]
#
# 191. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  178
#   # Optimal (ls, var) =  (0.7238306416790846, 82.85302262242936)
#     w:  [2.4936 4.5405],     f(w): 12.7309
#      d(w):  [2.6771 0.3433],     s.d:  [4.5038 6.2968],     g(w): [0.702  0.8962]
#
# 192. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  179
#     w:  [-5.4277  2.3956],     f(w): 13.6464
#      d(w):  [-2.2385  0.4185],     s.d:  [6.6215 6.9485],     g(w): [-1.7103  1.3158]
#
# 193. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  180
#     w:  [-0.322   4.3336],     f(w): 11.2752
#      d(w):  [-0.3601  1.1308],     s.d:  [6.0989 4.0262],     g(w): [-1.8809  3.2256]
# 194. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  181
#   # Optimal (ls, var) =  (0.7289735996946356, 79.64688138627218)
#     w:  [ 6.     -3.6928],     f(w): 13.9509
#      d(w):  [-4.4445 -2.5182],     s.d:  [10.7331  4.2329],     g(w): [0.8894 3.5204]
#
# 195. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  182
#     w:  [-1.4318  5.334 ],     f(w): 13.0664
#      d(w):  [-0.8764  2.018 ],     s.d:  [5.474  4.4054],     g(w): [-0.9798  2.5901]
#
# 196. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  183
#     w:  [3.4061 1.6759],     f(w): 10.4990
#      d(w):  [-0.0991  0.8543],     s.d:  [3.6793 4.9137],     g(w): [ 2.4058 -0.7507]
#
# 197. UCB suggests with (1 - Pr) =  1
#    UCB create new index  184
#   # Optimal (ls, var) =  (0.7249122212224398, 73.12173758753464)
#     w:  [-3.4106 -5.2647],     f(w): 13.8560
#      d(w):  [-1.2537 -1.3266],     s.d:  [6.6085 4.8763],     g(w): [-1.6796 -2.9343]
#
# 198. UCB suggests with (1 - Pr) =  1
#    UCB create new index  185
#     w:  [ 2.4026 -2.8761],     f(w): 9.9978
#      d(w):  [-0.5549 -2.0789],     s.d:  [3.1461 4.0685],     g(w): [2.7791 0.8143]
#
# 199. UCB suggests with (1 - Pr) =  1
#    UCB create new index  186
#     w:  [6.     3.6188],     f(w): 14.1514
#      d(w):  [-4.0646  1.5603],     s.d:  [6.3824 5.5598],     g(w): [ 0.8991 -1.8936]
#
# 200. UCB suggests with (1 - Pr) =  1
#    UCB create new index  187
#   # Optimal (ls, var) =  (0.6994831405823237, 37.057155485752695)
#     w:  [0.8297 1.3447],     f(w): 5.7625
#      d(w):  [ 0.1197 -0.2421],     s.d:  [2.2701 2.9391],     g(w): [-1.4596  4.4248]
#
# 201. UCB suggests with (1 - Pr) =  1
#    UCB create new index  188
#     w:  [ 1.9783 -1.8747],     f(w): 6.7798
#      d(w):  [-0.4002 -4.0569],     s.d:  [2.1666 3.168 ],     g(w): [0.4002 3.8754]
#
# 202. UCB suggests with (1 - Pr) =  1
#    UCB create new index  189
#     w:  [0.3117 0.0069],     f(w): 2.2171
#      d(w):  [8.5644 1.8777],     s.d:  [0.1395 0.4851],     g(w): [6.6724 0.2464]
#
# 203. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  190
#   # Optimal (ls, var) =  (0.7051301464582544, 53.012705653424845)
#     w:  [2.8885 0.1719],     f(w): 7.5797
#      d(w):  [7.8144 2.2607],     s.d:  [2.5864 3.2505],     g(w): [-1.8808  5.2519]
#
# 204. GD suggests with Pr =  1.0
#    GD (i, loop)  (189, 38)
#     w:  [ 0.0107 -0.0468],     f(w): 0.1963
#      d(w):  [ 0.2522 -2.3043],     s.d:  [0.0568 0.0447],     g(w): [ 1.1865 -5.1607]
#
# 205. GD suggests with Pr =  1.0
#    GD (i, loop)  (189, 49)
#     w:  [-0.0514  0.0208],     f(w): 0.2366
#      d(w):  [-2.2076  0.8056],     s.d:  [0.049 0.024],     g(w): [-5.2301  2.1294]
#
# 206. GD suggests with Pr =  1.0
#    GD (i, loop)  (189, 78)
#   # Optimal (ls, var) =  (0.4912050855717061, 81.83118374158748)
#     w:  [ 0.0067 -0.0079],     f(w): 0.0322
#      d(w):  [-2.235 -3.028],     s.d:  [0.1849 0.0491],     g(w): [ 2.189  -2.5753]
#
# 207. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  191
#     w:  [-0.8195  0.5723],     f(w): 4.5664
#      d(w):  [-32.5209  -0.7985],     s.d:  [9.0411 9.2709],     g(w): [0.2309 0.3196]
#
# 208. UCB suggests with (1 - Pr) =  1
#    UCB create new index  192
#     w:  [-1.1614 -0.2226],     f(w): 4.3791
#      d(w):  [-17.1546   2.516 ],     s.d:  [ 9.5298 10.5675],     g(w): [-6.1347 -4.8426]
#
# 209. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  193
#   # Optimal (ls, var) =  (0.48971253196902165, 63.028855478302575)
#     w:  [5.6179 5.2816],     f(w): 15.3705
#      d(w):  [0.3045 0.5478],     s.d:  [14.4572 13.8163],     g(w): [-0.6355  2.5808]
#
# 210. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  194
#     w:  [0.7496 0.6859],     f(w): 4.5741
#      d(w):  [16.4635 10.0977],     s.d:  [6.3871 7.8486],     g(w): [-0.7722 -0.7196]
#
# 211. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  195
#     w:  [-1.9478  1.4613],     f(w): 7.5567
#      d(w):  [-7.2748  3.3419],     s.d:  [11.7318 10.7384],     g(w): [-0.603   1.9502]
#
# 212. UCB suggests with (1 - Pr) =  0.9999999316656388
#    UCB create new index  196
#   # Optimal (ls, var) =  (0.493455424393375, 59.6222702038772)
#     w:  [-1.1633  1.6702],     f(w): 6.7019
#      d(w):  [-2.5213  4.2196],     s.d:  [9.066  9.5357],     g(w): [-3.9503 -1.0672]
#
# 213. UCB suggests with (1 - Pr) =  0.9999977307962346
#    UCB create new index  197
#     w:  [-0.4137 -5.1963],     f(w): 12.3803
#      d(w):  [ 2.4209 -2.743 ],     s.d:  [11.9656 12.7356],     g(w): [-1.3535 -3.6283]
#
# 214. UCB suggests with (1 - Pr) =  0.999945123915708
#    UCB create new index  198
#     w:  [ 0.2925 -0.9421],     f(w): 3.9239
#      d(w):  [  2.1713 -22.1705],     s.d:  [5.3178 4.7279],     g(w): [ 4.9677 -0.7865]
#
# 215. UCB suggests with (1 - Pr) =  0.9999820091469325
#    UCB create new index  199
#   # Optimal (ls, var) =  (0.4801648044054891, 92.57888596822953)
#     w:  [-0.1436  2.9963],     f(w): 7.3855
#      d(w):  [0.7147 0.0091],     s.d:  [16.4184 14.1828],     g(w): [-5.6297  1.6822]
#
# 216. UCB suggests with (1 - Pr) =  0.9969749553940868
#    UCB create new index  200
#     w:  [-2.3821 -3.9481],     f(w): 11.1890
#      d(w):  [-1.0841 -2.7507],     s.d:  [15.5784 16.9511],     g(w): [-3.1151 -0.144 ]
#
# 217. UCB suggests with (1 - Pr) =  0.9934786655871533
#    UCB create new index  201
#     w:  [-4.0201  5.1946],     f(w): 12.8712
#      d(w):  [-0.7537  1.5837],     s.d:  [16.9431 17.4421],     g(w): [-1.4536  6.6349]
#
# 218. GD suggests with Pr =  0.011687124245955003
#    GD (i, loop)  (192, 16)
#   # Optimal (ls, var) =  (0.4878278234404598, 47.10373180373199)
#     w:  [-1.0355 -0.2156],     f(w): 3.6837
#      d(w):  [-6.6598  4.8583],     s.d:  [0.9319 7.3194],     g(w): [-3.6427 -6.0594]
#
# 219. UCB suggests with (1 - Pr) =  1
#    UCB create new index  202
#     w:  [ 4.2592 -0.4181],     f(w): 11.1709
#      d(w):  [2.4204 1.9818],     s.d:  [11.0957 10.5685],     g(w): [ 3.5081 -1.1224]
#
# 220. UCB suggests with (1 - Pr) =  1
#    UCB create new index  203
#     w:  [ 5.2072 -4.0027],     f(w): 12.9352
#      d(w):  [ 2.2505 -1.4916],     s.d:  [11.788 11.405],     g(w): [ 6.5882 -0.7823]
#
# 221. UCB suggests with (1 - Pr) =  1
#    UCB create new index  204
#   # Optimal (ls, var) =  (0.4829528095165858, 65.7195274394207)
#     w:  [ 2.4851 -5.3087],     f(w): 13.4805
#      d(w):  [-0.5875 -1.2513],     s.d:  [14.0714 13.1932],     g(w): [ 0.6721 -2.6057]
#
# 222. UCB suggests with (1 - Pr) =  1
#    UCB create new index  205
#     w:  [-6.      0.7911],     f(w): 12.3466
#      d(w):  [5.4102 1.6549],     s.d:  [15.0727 12.5586],     g(w): [-1.1915 -5.5331]
#
# 223. UCB suggests with (1 - Pr) =  1
#    UCB create new index  206
#     w:  [ 1.3061 -3.4004],     f(w): 10.2089
#      d(w):  [-0.195  -1.8934],     s.d:  [12.3424 12.6014],     g(w): [ 2.2604 -2.6097]
#
# 224. UCB suggests with (1 - Pr) =  1
#    UCB create new index  207
#   # Optimal (ls, var) =  (0.4823813107133969, 87.90878344788418)
#     w:  [ 4.0795 -3.1536],     f(w): 11.0106
#      d(w):  [ 1.4441 -0.836 ],     s.d:  [16.6348 14.3388],     g(w): [ 4.1837 -6.1585]
#
# 225. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  208
#     w:  [ 3.2905 -2.3796],     f(w): 10.8431
#      d(w):  [0.9762 1.2282],     s.d:  [13.315  14.7102],     g(w): [ 3.1543 -2.2554]
#
# 226. UCB suggests with (1 - Pr) =  1
#    UCB create new index  209
#     w:  [-4.4181  2.5448],     f(w): 12.5931
#      d(w):  [-1.131   0.0937],     s.d:  [15.2499 15.6036],     g(w): [-1.8107  0.3373]
#
# 227. UCB suggests with (1 - Pr) =  1
#    UCB create new index  210
#   # Optimal (ls, var) =  (0.4833478645147749, 88.56292414841006)
#     w:  [-6.     -5.2776],     f(w): 14.7455
#      d(w):  [ 6.5342 -0.8461],     s.d:  [18.5605 13.8537],     g(w): [-0.686  -5.2841]
#
# 228. UCB suggests with (1 - Pr) =  1
#    UCB create new index  211
#     w:  [-1.8681 -5.3416],     f(w): 12.6663
#      d(w):  [ 0.0059 -1.4458],     s.d:  [16.7966 13.1091],     g(w): [ 2.0539 -4.0138]
#
# 229. UCB suggests with (1 - Pr) =  1
#    UCB create new index  212
#     w:  [-6.      5.2157],     f(w): 14.3858
#      d(w):  [7.2313 1.2596],     s.d:  [18.3398 14.8037],     g(w): [-0.6935  6.2339]
#
# 230. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  213
#   # Optimal (ls, var) =  (0.4857328254603167, 89.45160176669165)
#     w:  [2.8228 5.2917],     f(w): 13.0587
#      d(w):  [0.6542 2.1904],     s.d:  [15.596  14.2794],     g(w): [-2.5182  4.3935]
# 231. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  214
#     w:  [-3.9821  3.2284],     f(w): 11.2728
#      d(w):  [-1.2228 -1.8277],     s.d:  [14.3256 14.3116],     g(w): [-0.4434  6.337 ]
#
# 232. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  215
#     w:  [4.127 3.283],     f(w): 11.9518
#      d(w):  [-0.3362  1.673 ],     s.d:  [15.0516 15.2417],     g(w): [3.9272 4.7682]
#
# 233. UCB suggests with (1 - Pr) =  1
#    UCB create new index  216
#   # Optimal (ls, var) =  (0.4900948656950782, 60.03989901098898)
#     w:  [-0.7008 -2.9948],     f(w): 8.3570
#      d(w):  [-1.6266  0.6529],     s.d:  [10.3922 11.6804],     g(w): [ 3.8189 -1.6374]
#
# 234. UCB suggests with (1 - Pr) =  1
#    UCB create new index  217
#     w:  [-4.2391 -2.9283],     f(w): 11.4439
#      d(w):  [-2.4045 -0.4178],     s.d:  [11.7572 12.3558],     g(w): [-6.2099  1.4438]
#
# 235. UCB suggests with (1 - Pr) =  1
#    UCB create new index  218
#     w:  [0.8506 1.8872],     f(w): 5.8302
#      d(w):  [5.7537 6.5751],     s.d:  [7.1646 6.7993],     g(w): [-4.1114 -2.0913]
#
# 236. UCB suggests with (1 - Pr) =  1
#    UCB create new index  219
#   # Optimal (ls, var) =  (0.503292746192635, 35.50193249720298)
#     w:  [-3.1221  2.1194],     f(w): 8.9229
#      d(w):  [-1.1365  0.6253],     s.d:  [7.3446 8.6396],     g(w): [-5.8787  5.3564]
#
# 237. UCB suggests with (1 - Pr) =  1
#    UCB create new index  220
#     w:  [-0.5024  0.7546],     f(w): 4.5094
#      d(w):  [ 1.3874 20.8576],     s.d:  [2.3288 2.5055],     g(w): [-1.3498  0.1386]
#
# 238. UCB suggests with (1 - Pr) =  1
#    UCB create new index  221
#     w:  [-4.1677 -0.2294],     f(w): 10.2688
#      d(w):  [-1.1639  0.9025],     s.d:  [8.7859 7.5927],     g(w): [-5.295  -4.3418]
#
# 239. UCB suggests with (1 - Pr) =  1
#    UCB create new index  222
#   # Optimal (ls, var) =  (0.48210391566362026, 69.77563237237769)
#     w:  [-6.      3.6473],     f(w): 14.0886
#      d(w):  [8.4677 1.9784],     s.d:  [14.4764 12.9546],     g(w): [-0.8954 -2.5185]
#
# 240. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  223
#     w:  [-4.7036 -1.2834],     f(w): 11.9015
#      d(w):  [-2.6727 -0.3421],     s.d:  [12.8322 12.1463],     g(w): [ 0.9784 -2.7711]
#
# 241. UCB suggests with (1 - Pr) =  1.0
#    UCB create new index  224
#     w:  [ 3.8513 -6.    ],     f(w): 13.2024
#      d(w):  [2.2358 7.1958],     s.d:  [12.4019 15.7026],     g(w): [-5.05   -0.8684]
#
# 242. UCB suggests with (1 - Pr) =  1
#    UCB create new index  225
#   # Optimal (ls, var) =  (0.4838027966345184, 68.47108476044103)
#     w:  [-2.7173  5.2697],     f(w): 13.2222
#      d(w):  [-1.5506  1.5505],     s.d:  [14.0006 13.1375],     g(w): [2.0502 3.7333]
#
# 243. UCB suggests with (1 - Pr) =  1
#    UCB create new index  226
#     w:  [2.8735 2.6626],     f(w): 10.1323
#      d(w):  [0.0381 1.6896],     s.d:  [11.3692 13.4782],     g(w): [-1.2592 -1.824 ]
#
# 244. UCB suggests with (1 - Pr) =  1
#    UCB create new index  227
#     w:  [-1.6099  4.33  ],     f(w): 11.7774
#      d(w):  [-0.2168  1.0774],     s.d:  [13.3919 12.009 ],     g(w): [0.5565 2.8509]
#
# 245. UCB suggests with (1 - Pr) =  1
#    UCB create new index  228
#   # Optimal (ls, var) =  (0.48365601678293235, 87.80576806799102)
#     w:  [ 3.4899 -0.8372],     f(w): 9.8911
#      d(w):  [0.3636 0.8672],     s.d:  [12.7835 13.6937],     g(w): [1.8133 1.7155]
#
# 246. UCB suggests with (1 - Pr) =  1
#    UCB create new index  229
#     w:  [ 3.8168 -4.4808],     f(w): 13.2720
#      d(w):  [ 1.3165 -0.6648],     s.d:  [16.1894 12.927 ],     g(w): [-1.3433 -1.2189]
#
# 247. UCB suggests with (1 - Pr) =  1
#    UCB create new index  230
#     w:  [ 0.9288 -4.7495],     f(w): 11.0633
#      d(w):  [-0.469  -3.9781],     s.d:  [14.2434 13.2463],     g(w): [-1.8557  3.5232]
#
# 248. UCB suggests with (1 - Pr) =  1
#    UCB create new index  231
#   # Optimal (ls, var) =  (0.487425536558745, 79.7412773588937)
#     w:  [-2.6314 -5.5293],     f(w): 13.8699
#      d(w):  [-1.8413 -0.3627],     s.d:  [13.1116 13.2311],     g(w): [ 0.4948 -0.8238]
#
# 249. UCB suggests with (1 - Pr) =  1
#    UCB create new index  232
#     w:  [-5.3183  0.1193],     f(w): 12.1218
#      d(w):  [-1.3398  0.9072],     s.d:  [12.2001 14.7447],     g(w): [-4.6775  2.5359]
#
# 250. UCB suggests with (1 - Pr) =  1
#    UCB create new index  233
#     w:  [ 0.4537 -4.0068],     f(w): 10.3900
#      d(w):  [ 0.3808 -0.3545],     s.d:  [11.3787 13.2187],     g(w): [ 1.0991 -1.725 ]
#
# Max Cost reached =  251

# %%
# fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6)) = pl.subplots(3, 2, figsize=(20, 12))
# Posterior
mu, covar = gp.posterior(Grid)
mu = np.squeeze(mu)
s = np.sqrt(np.diag(covar))

fig, (ax1, ax2) = pl.subplots(1, 2, figsize=(25, 8))

# plot function
im = ax2.pcolormesh(X1, X2, s.reshape(X1.shape), cmap="jet", shading='auto')
fig.colorbar(im, ax=ax2)

im1 = ax1.contour(X1, X2, clean_f(Grid).reshape(X1.shape),  cmap="PuBuGn") 
im2 = ax1.contour(X1, X2, mu.reshape(X1.shape), cmap="YlOrRd")
# im2 = ax1.contour(X1, X2, clean_f(Grid).reshape(X1.shape), cmap="YlOrRd")

pl.clabel(im1, inline=True, fontsize=8)

fig.colorbar(im1, ax=ax1)
fig.colorbar(im2, ax=ax1)

ax1.plot(np.squeeze(gp.X[:, 0]), np.squeeze(gp.X[:, 1]), 'ko', linewidth=2)

ax1.title.set_text("Noisy Ackley via posterior derivative mean")
ax2.title.set_text("Standard deviation")
pl.show()

# %%
pl.figure(figsize=(13, 8), dpi=80)
pl.plot(np.squeeze(np.array(history)[:, 1]), "-^")
pl.xlabel("cost")
pl.plot(np.minimum.accumulate(np.array(history)[:, 1]), 'g', lw=2)
pl.ylabel("function value")
pl.grid(True)
# Out:
# <ipython-input-23-0b3d1842ec4f>:2: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   pl.plot(np.squeeze(np.array(history)[:, 1]), "-^")
# <ipython-input-23-0b3d1842ec4f>:4: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   pl.plot(np.minimum.accumulate(np.array(history)[:, 1]), 'g', lw=2)

# %% [markdown]
# ## Minima of GD

# %%
gp.X[np.argmin(gp.y)], np.min(gp.y), np.argmin(gp.y)
# Out:
# (array([ 0.0067, -0.0079]), 0.03219206956502818, 206)

# %%
gp.get_hyper()
# Out:
# {'var': 79.7412773588937, 'lengthscale': 0.487425536558745}

# %%
# # only for backtracking
# pl.figure(figsize=(10, 6), dpi=80)
# # pl.plot(history_lr, "-^")
# pl.title("learning rate as the algorithm runs")
# pl.xlabel("n_iter")
# pl.ylabel("learning rate")
# pl.yscale("log")
# pl.grid(True)

# %% [markdown]
# ### *UCB*

# %%
### Thompson Sampling
import os
gp.clear()
# gp.set_hyper(ls, var) # if online update hyper, skip

# init cost
X = np.asarray(np.random.uniform(lb, ub, size=(setup, dim)))
X = X_fix

gp.set_data(X, f(X))
gp.optimize()
gp.fit()

history_ucb = []

# %%
cost = setup + warmup
while cost < MAX:
    # 1. Thompson Sampling
#     w = gp.Thompson_sample(n_mesh=5000)

    
    # 2. GP_UCB/EI
#     b = np.log(cost**gp.dim)
#     b = cost**gp.dim
#     arg_min = np.argmin(mu.reshape(-1,1) - np.sqrt(b)*s.reshape(-1, 1)) # discrete version
#     w = Grid[arg_min]
#     w, fw = gp.ucb_minimize(b)
    w, fw = gp.EI_minimize(y_best=np.min(f(gp.X)))
    if is_new(w, gp.X) == False:
        print('visit before, ignore ', w)
        continue
    
    
#     fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6)) = pl.subplots(3, 2, figsize=(24, 21))

#     # plot function (ax1, ax2)
#     im = ax2.pcolormesh(X1, X2, s.reshape(X1.shape), cmap="jet", shading='auto')
#     fig.colorbar(im, ax=ax2)

#     im1 = ax1.contour(X1, X2, functions.Ackley_2().func(Grid).reshape(X1.shape), cmap="PuBuGn")
#     im2 = ax1.contour(X1, X2, mu.reshape(X1.shape), cmap="YlOrRd")

#     fig.colorbar(im1, ax=ax1)
#     fig.colorbar(im2, ax=ax1)

#     ax1.plot(gp.X[:, 0], gp.X[:, 1], "ok", markersize=5, alpha=0.8)
#     ax1.plot(w[0], w[1], 'ro')
#     ax1.title.set_text("Noisy Ackley")
#     ax2.title.set_text("Standard Deviation")
    
    
#     # plot derivative in (ax3, ax4), (ax5, ax6)
#     im = ax4.pcolormesh(X1, X2, s_grad_1.reshape(X1.shape), cmap="jet", shading='auto')
#     fig.colorbar(im, ax=ax4)
#     im1 = ax3.contour(X1, X2, g1.reshape(X1.shape), cmap="PuBuGn")
#     im2 = ax3.contour(X1, X2, mu_grad_1.reshape(X1.shape), cmap="YlOrRd")

#     fig.colorbar(im1, ax=ax3)
#     fig.colorbar(im2, ax=ax3)

#     ax3.plot(gp.X[:, 0], gp.X[:, 1], "ok", markersize=5, alpha=0.8)
#     ax3.title.set_text("Mean of Posterior Partial x")
#     ax4.title.set_text("Std of Posterior Partial x")

    
#     im3 = ax6.pcolormesh(X1, X2, s_grad_2.reshape(X1.shape), cmap="jet", shading='auto')
#     fig.colorbar(im3, ax=ax6)
#     im4 = ax5.contour(X1, X2, g2.reshape(X1.shape), cmap="PuBuGn")
#     im5 = ax5.contour(X1, X2, mu_grad_2.reshape(X1.shape), cmap="YlOrRd")

#     fig.colorbar(im4, ax=ax5)
#     fig.colorbar(im5, ax=ax5)

#     ax5.plot(gp.X[:, 0], gp.X[:, 1], "ok", markersize=5, alpha=0.8)
#     ax5.title.set_text("Mean of Posterior Partial y")
#     ax6.title.set_text("Std of Posterior Partial y")

#     filename = 'Ackley_' + str(i) + '_noise_TS' +'.png'
#     pl.savefig('2D_Plots/Ackley/' + filename)
#     pl.show()  
    print(cost, end = ', ')
    print('w: ', w, end = ', ')
    print('f(w): ', f(w).item(), end = ', ')
    print()
    
    history_ucb.append( (w, f(w)) )
    gp.add_data(w.reshape(1, dim), f(w))
    
    if cost % 3 == 0:
        ls, var = gp.optimize()
        gp.set_hyper(ls, var)
        print('  # Optimal (ls, var) = ', (ls, var))
    gp.fit()
    cost += 1
# Out:
# 3, w:  [-6.  6.], f(w):  13.97611576175596,
#   # Optimal (ls, var) =  (2.0, 100.0)
# 4, w:  [-6. -6.], f(w):  13.97611576175596,
# 5, w:  [0.5065 6.    ], f(w):  13.182773925983758,
# 6, w:  [-6.      0.0634], f(w):  11.543818088642599,
#   # Optimal (ls, var) =  (2.0, 100.0)
# 7, w:  [ 6.     -2.9508], f(w):  12.294602320648583,
# 8, w:  [1.1209 1.3231], f(w):  5.916490737597865,
# 9, w:  [-2.4082  2.3718], f(w):  9.852974709809555,
#   # Optimal (ls, var) =  (2.0, 100.0)
# 10, w:  [-2.0436 -6.    ], f(w):  11.889476287179273,
# 11, w:  [6. 6.], f(w):  13.97611576175596,
# 12, w:  [ 2.988  -0.4798], f(w):  8.679220468876302,
#   # Optimal (ls, var) =  (2.0, 100.0)
# 13, w:  [ 6. -6.], f(w):  13.97611576175596,
# 14, w:  [-3.4039 -2.3402], f(w):  11.060346360954966,
# 15, w:  [2.5547 3.1097], f(w):  10.479572673762943,
#   # Optimal (ls, var) =  (2.0, 97.73588734272404)
# 16, w:  [-2.6764  6.    ], f(w):  13.501090478605812,
# 17, w:  [-0.6054  0.2643], f(w):  3.857563924789059,
# 18, w:  [ 6.     -0.1156], f(w):  11.762956166664084,
#   # Optimal (ls, var) =  (2.0, 85.71014162377514)
# 19, w:  [-6.      2.8795], f(w):  12.543910348686433,
# 20, w:  [ 0.6973 -0.5254], f(w):  4.5225924877204235,
# 21, w:  [-6.    -2.821], f(w):  12.841815452644388,
#   # Optimal (ls, var) =  (2.0, 75.73605989652903)
# 22, w:  [-2.553   0.0134], f(w):  7.7534305339198255,
# 23, w:  [ 2.3481 -2.5291], f(w):  9.983845211298295,
# 24, w:  [3.1756 6.    ], f(w):  12.995200579874762,
#   # Optimal (ls, var) =  (2.0, 67.26020768067804)
# 25, w:  [-0.1827  2.7016], f(w):  8.024091569774674,
# 26, w:  [-0.0136  0.1529], f(w):  0.9558861483382981,
# 27, w:  [ 4.1345 -2.07  ], f(w):  10.1270571468508,
#   # Optimal (ls, var) =  (1.671377193228793, 98.84029293293733)
# 28, w:  [-4.0941  0.961 ], f(w):  9.223959248620094,
# 29, w:  [-0.9294 -3.7722], f(w):  9.488620998663936,
# 30, w:  [ 3.5388 -6.    ], f(w):  14.23550547859322,
#   # Optimal (ls, var) =  (1.6833364713687282, 92.95557061641821)
# 31, w:  [0.2955 0.4377], f(w):  3.61052766958861,
# 32, w:  [-0.3755 -0.534 ], f(w):  4.05182406024943,
# 33, w:  [3.0533 1.3915], f(w):  9.187185253420223,
#   # Optimal (ls, var) =  (1.1321841209719563, 100.0)
# 34, w:  [-3.8911  3.9718], f(w):  11.19796676217529,
# 35, w:  [-3.9345 -4.6961], f(w):  12.969745388814204,
# 36, w:  [-1.1058  4.2987], f(w):  10.766949060417112,
#   # Optimal (ls, var) =  (1.1660601369401846, 100.0)
# 37, w:  [1.2017 2.63  ], f(w):  8.606238222784794,
# 38, w:  [ 0.4402 -2.7897], f(w):  8.59331587346471,
# 39, w:  [4.2616 4.067 ], f(w):  12.502257204155265,
#   # Optimal (ls, var) =  (1.152271685917479, 100.0)
# 40, w:  [ 0.0064 -6.    ], f(w):  11.440200898462336,
# 41, w:  [ 3.9065 -3.9605], f(w):  11.149698053789084,
# 42, w:  [-3.9251 -0.6879], f(w):  10.04350971454046,
#   # Optimal (ls, var) =  (1.1669735491003257, 100.0)
# 43, w:  [-1.74  -2.546], f(w):  9.187260627254497,
# 44, w:  [4.7994 1.1096], f(w):  11.039403491155614,
# 45, w:  [1.7866 4.6575], f(w):  11.989078380456057,
#   # Optimal (ls, var) =  (1.173880754446243, 95.9626091603428)
# 46, w:  [-4.3186  6.    ], f(w):  14.34964052332542,
# 47, w:  [-4.1544  2.4348], f(w):  11.757384749960396,
# 48, w:  [ 4.4032 -0.5474], f(w):  11.628433119359737,
#   # Optimal (ls, var) =  (1.1859714255727847, 92.23122887093683)
# 49, w:  [-3.9053 -6.    ], f(w):  12.957231482358303,
# 50, w:  [ 0.0131 -0.0954], f(w):  0.5016363641345589,
# 51, w:  [-6.     4.393], f(w):  14.61619773142345,
#   # Optimal (ls, var) =  (1.202311030458548, 89.10267103008104)
# 52, w:  [-6.     -4.3499], f(w):  14.476567354970406,
# 53, w:  [1.9851 1.6337], f(w):  7.636238971774812,
# 54, w:  [4.0713 2.5325], f(w):  11.604677533230848,
#   # Optimal (ls, var) =  (1.1790616815643387, 86.76210411681143)
# 55, w:  [ 6.     -4.4254], f(w):  14.694559134624916,
# 56, w:  [-1.0771  6.    ], f(w):  11.706304001706526,
# 57, w:  [-2.8331  1.0484], f(w):  7.604019532139846,
#   # Optimal (ls, var) =  (1.1853043136364423, 83.39178995973766)
# 58, w:  [-6.     -1.3606], f(w):  13.142962048147611,
# 59, w:  [6.    4.366], f(w):  14.53373608546638,
# 60, w:  [-2.467  -4.1569], f(w):  11.81445300557182,
#   # Optimal (ls, var) =  (1.1933791074658708, 80.61845591392249)
# 61, w:  [ 6.     -1.5395], f(w):  13.374035654693177,
# 62, w:  [-4.5136 -3.164 ], f(w):  12.759993146454091,
# 63, w:  [-6.      1.4517], f(w):  13.341393154550872,
#   # Optimal (ls, var) =  (1.201402099480436, 78.7801064754209)
# 64, w:  [-2.4623  3.9424], f(w):  11.372114484217892,
# 65, w:  [ 0.3347 -1.4553], f(w):  6.045680505946958,
# 66, w:  [ 2.45  -3.895], f(w):  11.362508533435886,
#   # Optimal (ls, var) =  (1.203916227263078, 75.88368809144643)
# 67, w:  [4.5542 6.    ], f(w):  14.796514762558303,
# 68, w:  [6.     1.3321], f(w):  13.044281767854223,
# 69, w:  [-0.5846 -2.7033], f(w):  8.630256884980119,
#   # Optimal (ls, var) =  (1.1776286631293558, 73.96787922185722)
# 70, w:  [ 0.2167 -4.4604], f(w):  11.399403123116842,
# 71, w:  [-1.1505 -4.9957], f(w):  10.822888616476686,
# 72, w:  [-2.595  -1.3311], f(w):  8.959506697009834,
#   # Optimal (ls, var) =  (1.1770455246621656, 71.63512381482786)
# 73, w:  [3.0336 4.3494], f(w):  12.053176201628698,
# 74, w:  [0.2716 4.1315], f(w):  10.270398399103229,
# 75, w:  [-1.2242  1.7961], f(w):  6.760852925640819,
#   # Optimal (ls, var) =  (1.1743088135395945, 69.4440364361719)
# 76, w:  [-1.3154  2.9991], f(w):  8.781817171857014,
# 77, w:  [ 1.8919 -6.    ], f(w):  12.07005592737472,
# 78, w:  [3.5908 0.4188], f(w):  10.299103309049983,
#   # Optimal (ls, var) =  (1.1732258388991692, 67.73135749943854)
# 79, w:  [2.155  0.4716], f(w):  7.268438192983284,
# 80, w:  [ 4.6972 -5.2052], f(w):  14.321780695197571,
# 81, w:  [1.8585 6.    ], f(w):  12.232023869769998,
#   # Optimal (ls, var) =  (1.1741640154836541, 65.73894965297129)
# 82, w:  [ 4.8377 -3.2334], f(w):  12.56646749922485,
# 83, w:  [ 2.1552 -1.3972], f(w):  7.921997188892133,
# 84, w:  [-4.7028 -1.8492], f(w):  11.774080282789432,
#   # Optimal (ls, var) =  (1.1755972656539553, 63.9805939190386)
# 85, w:  [ 1.3186 -3.6233], f(w):  10.55709671589998,
# 86, w:  [-4.9641  3.5367], f(w):  13.271220481425638,
# 87, w:  [-4.9295e+00  3.2175e-03], f(w):  10.168048044215965,
#   # Optimal (ls, var) =  (1.1782698700799104, 62.3376768854258)
# 88, w:  [ 3.1455 -1.6701], f(w):  9.564949492516948,
# 89, w:  [-3.2974  4.9684], f(w):  12.702667125505116,
# 90, w:  [ 3.0501 -4.9687], f(w):  11.322624615815213,
#   # Optimal (ls, var) =  (1.181789073613683, 61.06802918159735)
# 91, w:  [0.2586 1.8153], f(w):  6.098472263284883,
# 92, w:  [-4.9652 -5.3319], f(w):  14.30679729972973,
# 93, w:  [-0.2132  5.0962], f(w):  11.304398354905025,
#   # Optimal (ls, var) =  (1.1859476027941733, 59.849765055381305)
# 94, w:  [-4.8029  4.9316], f(w):  13.308861856114545,
# 95, w:  [-3.3983  0.2306], f(w):  9.652227909649225,
# 96, w:  [-4.9854  1.66  ], f(w):  11.947085346183824,
#   # Optimal (ls, var) =  (1.17636580560182, 58.602474172549265)
# 97, w:  [-0.0037 -0.0786], f(w):  0.3795731075515083,
# 98, w:  [ 0.9736 -1.9612], f(w):  5.384158184529607,
# 99, w:  [ 1.6032 -0.3675], f(w):  6.389392573376895,
#   # Optimal (ls, var) =  (0.9337962525916121, 70.88588626952223)
# 100, w:  [-0.3151 -0.0726], f(w):  2.3285123817270024,
# 101, w:  [-1.5652  0.9041], f(w):  6.275296835999381,
# 102, w:  [ 1.2846 -1.202 ], f(w):  6.082006849990467,
#   # Optimal (ls, var) =  (0.630543884876065, 99.99999999508238)
# 103, w:  [-0.9167  0.8476], f(w):  3.8992969785228486,
# 104, w:  [-1.3354 -1.1496], f(w):  6.089456881215636,
# 105, w:  [-1.4405  0.2784], f(w):  5.891216101285423,
#   # Optimal (ls, var) =  (0.6257177970990168, 100.0)
# 106, w:  [1.0736 0.5289], f(w):  4.875767745101854,
# 107, w:  [-3.2524 -3.4207], f(w):  11.818915042764527,
# 108, w:  [ 3.3984 -2.9752], f(w):  11.062533831542556,
#   # Optimal (ls, var) =  (0.6266472725560063, 99.84051532061116)
# 109, w:  [1.3041 3.6219], f(w):  10.52424628301055,
# 110, w:  [-1.9035  5.058 ], f(w):  10.99909801065705,
# 111, w:  [-2.8603 -5.268 ], f(w):  12.849979836718166,
#   # Optimal (ls, var) =  (0.6307684274333385, 97.75178105573731)
# 112, w:  [-3.2306  3.0511], f(w):  10.341688825466923,
# 113, w:  [ 4.946  -1.5924], f(w):  12.071686498280346,
# 114, w:  [0.6041 1.0601], f(w):  4.817857008024458,
#   # Optimal (ls, var) =  (0.6312019171242736, 98.77180305200305)
# 115, w:  [4.9227 4.9236], f(w):  12.82211172539824,
# 116, w:  [4.9949 3.2346], f(w):  12.367840135263785,
# 117, w:  [-0.4846 -1.1615], f(w):  5.187647829561524,
#   # Optimal (ls, var) =  (0.6272663829890915, 97.66401233882632)
# 118, w:  [-3.3392  1.7999], f(w):  10.127667605676669,
# 119, w:  [-4.8901 -4.0954], f(w):  12.382058194402662,
# 120, w:  [ 1.4195 -2.5904], f(w):  9.123980177796684,
#   # Optimal (ls, var) =  (0.6296235300573844, 92.74597981421387)
# 121, w:  [-2.0979  1.5775], f(w):  7.953104897813088,
# 122, w:  [2.9884 2.2967], f(w):  9.556949516970178,
# 123, w:  [-1.0099 -6.    ], f(w):  11.543337028770207,
#   # Optimal (ls, var) =  (0.6330512360487401, 99.90746093587832)
# 124, w:  [ 1.1029 -0.68  ], f(w):  4.862435804917165,
# 125, w:  [ 0.7297 -1.0945], f(w):  4.693085450339527,
# 126, w:  [3.9569 1.5213], f(w):  10.750484818777151,
#   # Optimal (ls, var) =  (0.6097464302265683, 87.28033860621075)
# 127, w:  [ 0.9087 -6.    ], f(w):  11.730756237475212,
# 128, w:  [-1.8955 -3.4301], f(w):  10.282856900866026,
# 129, w:  [3.7571 5.0796], f(w):  12.948351065296414,
#   # Optimal (ls, var) =  (0.6152312395809411, 98.14388224482437)
# 130, w:  [5.0213 0.1848], f(w):  10.88818529518904,
# 131, w:  [0.8693 4.9689], f(w):  10.622479317582702,
# 132, w:  [5.0583 2.0911], f(w):  11.067412192056446,
#   # Optimal (ls, var) =  (0.6160185675696194, 90.00003877859423)
# 133, w:  [3.5051 3.3458], f(w):  12.182130357145866,
# 134, w:  [-4.984 -0.896], f(w):  10.499775189225433,
# 135, w:  [-2.03   -0.7155], f(w):  6.499260749936607,
#   # Optimal (ls, var) =  (0.615319072803567, 85.65964486859106)
# 136, w:  [-1.7616 -1.7143], f(w):  7.663152008884657,
# 137, w:  [-2.5449 -2.547 ], f(w):  10.31521781855894,
# 138, w:  [-0.4614  3.5528], f(w):  10.284634644706784,
#   # Optimal (ls, var) =  (0.6168310235039804, 85.9681333036593)
# 139, w:  [ 0.0653 -3.5529], f(w):  9.632526512065514,
# 140, w:  [-0.5815  2.1003], f(w):  7.054525323055319,
# 141, w:  [ 4.8229 -6.    ], f(w):  13.928346269159668,
#   # Optimal (ls, var) =  (0.622315560606207, 96.29396598630451)
# 142, w:  [-3.6051 -1.4653], f(w):  10.769730487596942,
# 143, w:  [ 4.8991 -4.2221], f(w):  13.072468353580277,
# 144, w:  [ 2.3381 -0.223 ], f(w):  7.534155818237258,
#   # Optimal (ls, var) =  (0.617115898198954, 76.69825294499974)
# 145, w:  [ 3.7232 -1.1067], f(w):  9.810675042503762,
# 146, w:  [ 1.6242 -1.8416], f(w):  7.665668697059319,
# 147, w:  [-2.985  -0.6246], f(w):  8.570632002711891,
#   # Optimal (ls, var) =  (0.6218375627642895, 88.1834711659174)
# 148, w:  [0.9492 1.9676], f(w):  5.410610665017572,
# 149, w:  [2.5842 5.2054], f(w):  13.180407171068033,
# 150, w:  [0.4898 3.1649], f(w):  9.2194075730758,
#   # Optimal (ls, var) =  (0.6200624544765152, 78.12441457901225)
# 151, w:  [-2.102   3.1812], f(w):  9.213213851039342,
# 152, w:  [-1.6677 -4.396 ], f(w):  11.907024785423742,
# 153, w:  [ 0.0533 -2.1682], f(w):  5.95058983281621,
#   # Optimal (ls, var) =  (0.6225609778249529, 79.29221487823344)
# 154, w:  [-1.061   0.5548], f(w):  4.840424640056508,
# 155, w:  [-2.135   0.6372], f(w):  7.118613962981353,
# 156, w:  [-0.2751 -5.1507], f(w):  11.836584427046944,
#   # Optimal (ls, var) =  (0.604386887491189, 79.44819488887298)
# 157, w:  [1.9987 2.4345], f(w):  8.865149642460594,
# 158, w:  [-5.1041  0.788 ], f(w):  11.409800850303238,
# 159, w:  [-0.378  1.38 ], f(w):  5.897745141118612,
#   # Optimal (ls, var) =  (0.6066091206630262, 80.05186281059362)
# 160, w:  [-5.0922  2.5511], f(w):  12.835173725262132,
# 161, w:  [2.1947 3.8554], f(w):  10.42632657069636,
# 162, w:  [ 1.0128 -0.0383], f(w):  2.714008489400357,
#   # Optimal (ls, var) =  (0.6061621014135133, 74.14160330480834)
# 163, w:  [ 1.0851 -4.442 ], f(w):  11.27875335293586,
# 164, w:  [ 3.8794 -4.8118], f(w):  12.635819228853718,
# 165, w:  [ 2.6723 -6.    ], f(w):  13.514191511081783,
#   # Optimal (ls, var) =  (0.6072182711530244, 73.37101765930134)
# 166, w:  [-1.8045 -0.2187], f(w):  5.947661249149878,
# 167, w:  [ 5.1385 -2.4028], f(w):  12.83519583370128,
# 168, w:  [-1.1234 -2.1389], f(w):  6.535891228395986,
#   # Optimal (ls, var) =  (0.6105289165781534, 80.48554500522233)
# 169, w:  [2.8068 0.6093], f(w):  8.585568413476942,
# 170, w:  [-2.9768 -6.    ], f(w):  12.258061581886196,
# 171, w:  [ 5.3395 -0.7395], f(w):  12.645622228595634,
#   # Optimal (ls, var) =  (0.6062425855986877, 66.27997969346711)
# 172, w:  [-5.212  -2.5036], f(w):  13.206741810926118,
# 173, w:  [ 2.2618 -4.6929], f(w):  12.336351848783282,
# 174, w:  [-4.8816 -6.    ], f(w):  13.638363578814497,
#   # Optimal (ls, var) =  (0.609550381974278, 72.60490155771257)
# 175, w:  [-3.9223 -3.8724], f(w):  11.343756951747462,
# 176, w:  [-1.8496  6.    ], f(w):  12.278176160188377,
# 177, w:  [-4.2261  0.1526], f(w):  10.284666137458137,
#   # Optimal (ls, var) =  (0.610975887493396, 66.62860960762774)
# 178, w:  [-0.075  -0.7312], f(w):  3.2208745361379454,
# 179, w:  [-1.6097  3.7604], f(w):  10.800826709915682,
# 180, w:  [-6.     -5.1671], f(w):  14.076945051820049,
#   # Optimal (ls, var) =  (0.61472400602009, 81.20119895595204)
# 181, w:  [6.     5.1888], f(w):  14.215451821183613,
# 182, w:  [5.1713 4.0218], f(w):  12.718857424733432,
# 183, w:  [-0.3016  6.    ], f(w):  12.760800779778197,
#   # Optimal (ls, var) =  (0.6087687981301994, 64.39437085589164)
# 184, w:  [-0.078  -0.0347], f(w):  0.42572880026748594,
# 185, w:  [0.4306 0.1596], f(w):  3.1441314731793537,
# 186, w:  [-1.1578 -0.1614], f(w):  4.053730339850826,
#   # Optimal (ls, var) =  (0.5758087159962664, 71.7290874942118)
# 187, w:  [1.4835 0.1499], f(w):  5.7045801151711615,
# 188, w:  [ 2.0716 -3.1942], f(w):  9.182402289105674,
# 189, w:  [-5.5613 -3.5217], f(w):  14.451083304954786,
#   # Optimal (ls, var) =  (0.5656165618726584, 57.96451277444684)
# 190, w:  [0.4855 2.3938], f(w):  8.149628539396343,
# 191, w:  [-5.1694  6.    ], f(w):  14.09148543467623,
# 192, w:  [-3.4996  6.    ], f(w):  14.229402756830206,
#   # Optimal (ls, var) =  (0.5717595704419357, 72.61792997647089)
# 193, w:  [2.2677 1.0739], f(w):  7.213552459658466,
# 194, w:  [-1.0474  5.1254], f(w):  10.879137399722202,
# 195, w:  [0.0444 0.0265], f(w):  0.21636685943059364,
#   # Optimal (ls, var) =  (0.566856224303017, 83.9266319111786)
# 196, w:  [-1.987  -5.1312], f(w):  11.222052848038544,
# 197, w:  [ 3.1884 -4.0352], f(w):  11.08708719478555,
# 198, w:  [ 6.     -5.2144], f(w):  14.378027834523172,
#   # Optimal (ls, var) =  (0.5638727572042675, 71.61692876296566)
# 199, w:  [-6.      5.2011], f(w):  14.294361007894066,
# 200, w:  [ 0.6428 -5.2011], f(w):  12.335280781260998,
# 201, w:  [-0.5793 -4.3666], f(w):  11.529604727958645,
#   # Optimal (ls, var) =  (0.5700977077295222, 88.46350617504451)
# 202, w:  [ 2.2003 -0.82  ], f(w):  6.92701294449345,
# 203, w:  [-3.1984 -4.387 ], f(w):  12.634989656058268,
# 204, w:  [-4.1408 -2.4286], f(w):  11.699742136126286,
#   # Optimal (ls, var) =  (0.5639188569204711, 66.20158466435298)
# 205, w:  [6.     3.5578], f(w):  14.22745200846176,
# 206, w:  [4.315  0.4515], f(w):  11.38094984102261,
# 207, w:  [ 4.1517 -2.893 ], f(w):  10.964980542730597,
#   # Optimal (ls, var) =  (0.5674100618400924, 74.05881959779927)
# 208, w:  [ 6.     -3.6577], f(w):  14.061089529859611,
# 209, w:  [-4.1002  3.2154], f(w):  11.477848483641619,
# 210, w:  [6.     0.5917], f(w):  13.108469102034588,
#   # Optimal (ls, var) =  (0.5612986129682102, 53.70540037637288)
# 211, w:  [-1.6281  2.3928], f(w):  8.957524353185514,
# 212, w:  [-1.2076 -3.0466], f(w):  8.295432293581555,
# 213, w:  [-6.      3.6165], f(w):  14.155692218284667,
#   # Optimal (ls, var) =  (0.5613540589506745, 51.583271890419056)
# 214, w:  [-6.    -2.089], f(w):  12.055743742277588,
# 215, w:  [-2.5683  4.7331], f(w):  12.777605818654896,
# 216, w:  [ 3.1374 -2.3274], f(w):  10.112002674270231,
#   # Optimal (ls, var) =  (0.5638847497715387, 56.349483036640926)
# 217, w:  [-4.05    4.8295], f(w):  12.472413819765855,
# 218, w:  [ 3.6712 -0.3037], f(w):  10.171036483274182,
# 219, w:  [-6.     -0.6135], f(w):  13.065549541350347,
#   # Optimal (ls, var) =  (0.5657065889910211, 59.18416799332473)
# 220, w:  [-6.      2.1776], f(w):  12.555111621837012,
# 221, w:  [-4.1534  1.6421], f(w):  11.111900164562444,
# 222, w:  [-3.4405  1.0263], f(w):  9.653025053935407,
#   # Optimal (ls, var) =  (0.5798562812678653, 98.73051161086907)
# 223, w:  [-3.1869  3.9452], f(w):  11.013930395122022,
# 224, w:  [1.3085 5.5216], f(w):  13.245110492495925,
# 225, w:  [ 6.     -2.2494], f(w):  12.985287296962635,
#   # Optimal (ls, var) =  (0.5640887206535723, 51.379530078614245)
# 226, w:  [-0.8526  2.6035], f(w):  8.235252590228594,
# 227, w:  [2.5222 1.8358], f(w):  9.064787946542964,
# 228, w:  [-0.0657 -1.2021], f(w):  4.015745317343715,
#   # Optimal (ls, var) =  (0.5722483765148685, 74.35337981282784)
# 229, w:  [ 0.6654 -3.7106], f(w):  10.29630915527724,
# 230, w:  [-4.7847  4.2286], f(w):  13.420213073900307,
# 231, w:  [ 2.7426 -3.1874], f(w):  10.49986741599587,
#   # Optimal (ls, var) =  (0.5627402882273999, 49.27589315688878)
# 232, w:  [1.8273 3.1411], f(w):  9.023114980065257,
# 233, w:  [6.     2.0637], f(w):  11.952029250001155,
# 234, w:  [-1.1442 -1.5894], f(w):  6.665081005471002,
#   # Optimal (ls, var) =  (0.5654322012633786, 53.258131473467174)
# 235, w:  [-0.3968  4.3956], f(w):  11.552274417350311,
# 236, w:  [1.0177 4.2881], f(w):  10.53485139268893,
# 237, w:  [5.2813 6.    ], f(w):  14.765069473014316,
#   # Optimal (ls, var) =  (0.5759647136074687, 79.06861776095856)
# 238, w:  [-1.5687  1.3783], f(w):  7.389719244648944,
# 239, w:  [-2.7283  1.6656], f(w):  9.266352624875807,
# 240, w:  [-4.3297 -1.2296], f(w):  11.29721168212151,
#   # Optimal (ls, var) =  (0.5581842579871923, 37.08145883647982)
# 241, w:  [-2.739  -1.9254], f(w):  8.752416603302724,
# 242, w:  [-0.849   1.4002], f(w):  5.960085706065438,
# 243, w:  [-6.      0.7304], f(w):  12.660381587266125,
#   # Optimal (ls, var) =  (0.5673736393299552, 57.87656441803853)
# 244, w:  [1.6571 0.926 ], f(w):  6.240241400374167,
# 245, w:  [-0.5288  0.9198], f(w):  4.557422290587478,
# 246, w:  [-3.2429  2.4322], f(w):  10.79611421888148,
#   # Optimal (ls, var) =  (0.5692503340283259, 64.93171843634741)
# 247, w:  [4.2761 3.272 ], f(w):  12.51844621948168,
# 248, w:  [3.8378 6.    ], f(w):  13.27102251597655,
# 249, w:  [ 2.886  -1.0899], f(w):  7.565372179619207,
#   # Optimal (ls, var) =  (0.5780513075067977, 86.76544038896044)

# %%
pl.figure(figsize=(13, 8), dpi=80)
pl.plot(np.squeeze(np.array(history_ucb)[:, 1]), "-^")
pl.xlabel("cost")
pl.plot(np.minimum.accumulate(np.array(history_ucb)[:, 1]), 'r', lw=2)
pl.ylabel("function value")
pl.grid(True)
# Out:
# <ipython-input-30-cd275ce39db1>:2: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   pl.plot(np.squeeze(np.array(history_ucb)[:, 1]), "-^")
# <ipython-input-30-cd275ce39db1>:4: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   pl.plot(np.minimum.accumulate(np.array(history_ucb)[:, 1]), 'r', lw=1)

# %%
# fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6)) = pl.subplots(3, 2, figsize=(20, 12))
# Posterior
mu, covar = gp.posterior(Grid)
mu = np.squeeze(mu)
s = np.sqrt(np.diag(covar))

fig, (ax1, ax2) = pl.subplots(1, 2, figsize=(25, 8))

# plot function
im = ax2.pcolormesh(X1, X2, s.reshape(X1.shape), cmap="jet", shading='auto')
fig.colorbar(im, ax=ax2)

im1 = ax1.contour(X1, X2, clean_f(Grid).reshape(X1.shape),  cmap="PuBuGn") 
im2 = ax1.contour(X1, X2, mu.reshape(X1.shape), cmap="YlOrRd")
# im2 = ax1.contour(X1, X2, clean_f(Grid).reshape(X1.shape), cmap="YlOrRd")

pl.clabel(im1, inline=True, fontsize=8)

fig.colorbar(im1, ax=ax1)
fig.colorbar(im2, ax=ax1)

ax1.plot(np.squeeze(gp.X[:, 0]), np.squeeze(gp.X[:, 1]), 'ko', linewidth=2)

ax1.title.set_text("Noisy Ackley via posterior derivative mean")
ax2.title.set_text("Standard deviation")
pl.show()

# %% [markdown]
# ## Global Minima

# %%
gp.X[np.argmin(gp.y)], np.min(gp.y), np.argmin(gp.y)
# Out:
# (array([0.0444, 0.0265]), 0.21636685943059364, 195)

# %%
gp.get_hyper()
# Out:
# {'var': 86.76544038896044, 'lengthscale': 0.5780513075067977}

# %%
gp.EI(w, y_best)
# Out:
# -0.0

# %% [markdown]
# ### EI

# %%
### Thompson Sampling
import os
gp.clear()
# gp.set_hyper(ls, var) # if online update hyper, skip

# init cost
X = np.asarray(np.random.uniform(lb, ub, size=(setup, dim)))
X = X_fix

gp.set_data(X, f(X))
gp.optimize()
gp.fit()

history_EI = []

# %%
cost = setup + warmup
while cost < MAX:
    # 1. Thompson Sampling
#     w = gp.Thompson_sample(n_mesh=5000)

    
    # 2. GP_UCB/EI
#     b = np.log(cost**gp.dim)
#     b = cost**gp.dim
#     arg_min = np.argmin(mu.reshape(-1,1) - np.sqrt(b)*s.reshape(-1, 1)) # discrete version
#     w = Grid[arg_min]
#     w, fw = gp.ucb_minimize(b)
    w, fw = gp.EI_minimize(y_best=np.min(f(gp.X)))
    if is_new(w, gp.X) == False:
        print('visit before, ignore ', w)
        continue
    
    
#     fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6)) = pl.subplots(3, 2, figsize=(24, 21))

#     # plot function (ax1, ax2)
#     im = ax2.pcolormesh(X1, X2, s.reshape(X1.shape), cmap="jet", shading='auto')
#     fig.colorbar(im, ax=ax2)

#     im1 = ax1.contour(X1, X2, functions.Ackley_2().func(Grid).reshape(X1.shape), cmap="PuBuGn")
#     im2 = ax1.contour(X1, X2, mu.reshape(X1.shape), cmap="YlOrRd")

#     fig.colorbar(im1, ax=ax1)
#     fig.colorbar(im2, ax=ax1)

#     ax1.plot(gp.X[:, 0], gp.X[:, 1], "ok", markersize=5, alpha=0.8)
#     ax1.plot(w[0], w[1], 'ro')
#     ax1.title.set_text("Noisy Ackley")
#     ax2.title.set_text("Standard Deviation")
    
    
#     # plot derivative in (ax3, ax4), (ax5, ax6)
#     im = ax4.pcolormesh(X1, X2, s_grad_1.reshape(X1.shape), cmap="jet", shading='auto')
#     fig.colorbar(im, ax=ax4)
#     im1 = ax3.contour(X1, X2, g1.reshape(X1.shape), cmap="PuBuGn")
#     im2 = ax3.contour(X1, X2, mu_grad_1.reshape(X1.shape), cmap="YlOrRd")

#     fig.colorbar(im1, ax=ax3)
#     fig.colorbar(im2, ax=ax3)

#     ax3.plot(gp.X[:, 0], gp.X[:, 1], "ok", markersize=5, alpha=0.8)
#     ax3.title.set_text("Mean of Posterior Partial x")
#     ax4.title.set_text("Std of Posterior Partial x")

    
#     im3 = ax6.pcolormesh(X1, X2, s_grad_2.reshape(X1.shape), cmap="jet", shading='auto')
#     fig.colorbar(im3, ax=ax6)
#     im4 = ax5.contour(X1, X2, g2.reshape(X1.shape), cmap="PuBuGn")
#     im5 = ax5.contour(X1, X2, mu_grad_2.reshape(X1.shape), cmap="YlOrRd")

#     fig.colorbar(im4, ax=ax5)
#     fig.colorbar(im5, ax=ax5)

#     ax5.plot(gp.X[:, 0], gp.X[:, 1], "ok", markersize=5, alpha=0.8)
#     ax5.title.set_text("Mean of Posterior Partial y")
#     ax6.title.set_text("Std of Posterior Partial y")

#     filename = 'Ackley_' + str(i) + '_noise_TS' +'.png'
#     pl.savefig('2D_Plots/Ackley/' + filename)
#     pl.show()  
    print(cost, end = ', ')
    print('w: ', w, end = ', ')
    print('f(w): ', f(w).item(), end = ', ')
    print()
    
    history_EI.append( (w, f(w)) )
    gp.add_data(w.reshape(1, dim), f(w))
    
    if cost % 3 == 0:
        ls, var = gp.optimize()
        gp.set_hyper(ls, var)
        print('  # Optimal (ls, var) = ', (ls, var))
    gp.fit()
    cost += 1
# Out:
# 3, w:  [3.5788 0.2539], f(w):  10.040816625390189,
#   # Optimal (ls, var) =  (2.0, 98.54411749159968)
# 4, w:  [-6.  6.], f(w):  13.97611576175596,
# 5, w:  [-6. -6.], f(w):  13.97611576175596,
# 6, w:  [0.4628 6.    ], f(w):  13.165259843326773,
#   # Optimal (ls, var) =  (2.0, 100.0)
# 7, w:  [-6.      0.0575], f(w):  11.525904465693166,
# 8, w:  [ 6. -6.], f(w):  13.97611576175596,
# 9, w:  [-1.7014  1.9735], f(w):  7.473873637632153,
#   # Optimal (ls, var) =  (2.0, 100.0)
# 10, w:  [6. 6.], f(w):  13.97611576175596,
# 11, w:  [-2.0133 -6.    ], f(w):  11.832803106164459,
# 12, w:  [ 6.     -1.9225], f(w):  11.94864388202876,
#   # Optimal (ls, var) =  (2.0, 100.0)
# 13, w:  [1.2534 1.9716], f(w):  6.7273882486548935,
# 14, w:  [-3.389  -2.3184], f(w):  10.974600686626996,
# 15, w:  [-2.7328  6.    ], f(w):  13.2837791314136,
#   # Optimal (ls, var) =  (2.0, 98.93962171525244)
# 16, w:  [ 1.0186 -0.5795], f(w):  4.713434172767592,
# 17, w:  [-6.     2.864], f(w):  12.618201456000012,
# 18, w:  [ 2.1486 -2.2082], f(w):  8.249004405410016,
#   # Optimal (ls, var) =  (2.0, 85.00030299483856)
# 19, w:  [-0.5369  0.209 ], f(w):  3.585189062454241,
# 20, w:  [-6.     -2.8255], f(w):  12.817797084518041,
# 21, w:  [-2.5902  0.1369], f(w):  7.950963796018517,
#   # Optimal (ls, var) =  (2.0, 75.01799971169187)
# 22, w:  [3.018  4.5258], f(w):  12.448180183344249,
# 23, w:  [0.2091 0.6128], f(w):  3.6913379979302765,
# 24, w:  [-0.0234 -0.0721], f(w):  0.36069183015302686,
#   # Optimal (ls, var) =  (1.6127264579168998, 100.0)
# 25, w:  [-3.26   2.866], f(w):  10.540890712783847,
# 26, w:  [ 3.7619 -3.5226], f(w):  12.436155754722295,
# 27, w:  [-0.6404  3.6289], f(w):  10.325800455719806,
#   # Optimal (ls, var) =  (1.59487649072376, 100.0)
# 28, w:  [6.     0.4059], f(w):  13.085386089977654,
# 29, w:  [3.3391 2.2704], f(w):  10.700226073369727,
# 30, w:  [ 0.0209 -0.5222], f(w):  3.142697505032715,
#   # Optimal (ls, var) =  (1.1871277324715257, 100.0)
# 31, w:  [-0.9249 -3.3734], f(w):  9.422730919389034,
# 32, w:  [-3.9168 -4.7011], f(w):  12.974552957034364,
# 33, w:  [ 3.5695 -6.    ], f(w):  14.218828249197678,
#   # Optimal (ls, var) =  (1.2017416554069473, 100.0)
# 34, w:  [1.3806 3.4066], f(w):  10.36836274410069,
# 35, w:  [1.6366 0.4397], f(w):  6.527081692187171,
# 36, w:  [-4.0859  0.8319], f(w):  9.664535787301833,
#   # Optimal (ls, var) =  (1.2036332432519443, 100.0)
# 37, w:  [3.5889 6.    ], f(w):  14.198455835750806,
# 38, w:  [-1.8275 -1.7524], f(w):  7.464572665818945,
# 39, w:  [ 6.     -3.8929], f(w):  13.007019390492275,
#   # Optimal (ls, var) =  (1.2155401762204316, 100.0)
# 40, w:  [ 0.0195 -6.    ], f(w):  11.44936083113139,
# 41, w:  [ 3.8146 -1.4469], f(w):  10.726695102290204,
# 42, w:  [ 0.7611 -3.1766], f(w):  8.823483659803895,
#   # Optimal (ls, var) =  (1.232418815604494, 100.0)
# 43, w:  [-4.4085  4.5784], f(w):  14.154409207447369,
# 44, w:  [-4.285  -0.9114], f(w):  10.583845029341273,
# 45, w:  [0.3396 0.0282], f(w):  2.4063453976437725,
#   # Optimal (ls, var) =  (1.056896681689466, 100.0)
# 46, w:  [ 2.1385 -0.7563], f(w):  6.798796068699941,
# 47, w:  [4.8652 4.1722], f(w):  12.877338316406297,
# 48, w:  [-2.0826  4.2174], f(w):  10.725952578778148,
#   # Optimal (ls, var) =  (1.037342006777068, 100.0)
# 49, w:  [-2.3846 -3.9495], f(w):  11.196873966848946,
# 50, w:  [-1.1371  6.    ], f(w):  12.002330687435501,
# 51, w:  [ 1.1568 -1.7674], f(w):  6.4908194064888605,
#   # Optimal (ls, var) =  (1.0507985650728489, 100.0)
# 52, w:  [-0.1139  2.3175], f(w):  7.125579980658429,
# 53, w:  [-6.     -4.3621], f(w):  14.520273407447533,
# 54, w:  [2.4587 1.2505], f(w):  8.562614678029043,
#   # Optimal (ls, var) =  (1.0581971713297695, 96.9170146233591)
# 55, w:  [4.6588 1.4904], f(w):  12.241335563982874,
# 56, w:  [-3.9305 -6.    ], f(w):  12.872220094332652,
# 57, w:  [-2.8991  1.462 ], f(w):  9.161806952475,
#   # Optimal (ls, var) =  (1.063334754717912, 93.58329423462719)
# 58, w:  [1.9845 6.    ], f(w):  11.823940630563628,
# 59, w:  [-6.     -1.3879], f(w):  13.220843222917717,
# 60, w:  [-6.      1.4294], f(w):  13.30875940537174,
#   # Optimal (ls, var) =  (1.070583081098674, 89.8203000667289)
# 61, w:  [ 2.2259 -3.6972], f(w):  10.938300176750706,
# 62, w:  [-3.0709 -0.7556], f(w):  8.33250867182962,
# 63, w:  [-4.4803 -3.1959], f(w):  12.815335859434517,
#   # Optimal (ls, var) =  (1.0751944081335516, 87.67654963993621)
# 64, w:  [ 4.8742 -0.6387], f(w):  11.708505603302179,
# 65, w:  [-1.806  2.906], f(w):  8.590888582374403,
# 66, w:  [-6.      4.3395], f(w):  14.436869380816319,
#   # Optimal (ls, var) =  (1.074145061055116, 84.66637687838686)
# 67, w:  [-4.3102  6.    ], f(w):  14.311941221328738,
# 68, w:  [-0.2258 -4.6066], f(w):  11.571879496215349,
# 69, w:  [0.6213 4.5954], f(w):  11.876814067398172,
#   # Optimal (ls, var) =  (1.0794087131669292, 81.95570803012096)
# 70, w:  [-4.5894  2.5972], f(w):  12.795977352135083,
# 71, w:  [-0.1148  0.0065], f(w):  0.642136408939614,
# 72, w:  [-0.8472 -2.4277], f(w):  7.965212431903803,
#   # Optimal (ls, var) =  (0.8878217953935755, 93.34167399469453)
# 73, w:  [0.1417 1.4991], f(w):  5.723561000339959,
# 74, w:  [-1.6517  0.8126], f(w):  6.395569576480007,
# 75, w:  [-1.6974 -0.5753], f(w):  6.651302723324335,
#   # Optimal (ls, var) =  (0.868404568761892, 91.9768979360659)
# 76, w:  [ 4.6581 -4.8163], f(w):  14.032707750455286,
# 77, w:  [ 2.0577 -6.    ], f(w):  11.931564136250824,
# 78, w:  [ 4.7303 -2.5609], f(w):  12.780349429924804,
#   # Optimal (ls, var) =  (0.8727183515006636, 90.09412943332062)
# 79, w:  [2.7277 3.2563], f(w):  10.835571266358777,
# 80, w:  [6.    4.441], f(w):  14.724527485162387,
# 81, w:  [4.2441 3.0457], f(w):  11.51846787461476,
#   # Optimal (ls, var) =  (0.8760340105484276, 88.1309563679452)
# 82, w:  [-1.4218 -4.6653], f(w):  12.184816791703145,
# 83, w:  [-0.8037  1.3853], f(w):  5.961333714564571,
# 84, w:  [-3.2149  4.2807], f(w):  12.324159948362645,
#   # Optimal (ls, var) =  (0.879193641987079, 85.6668339188428)
# 85, w:  [ 3.022  -4.6984], f(w):  12.24247189710844,
# 86, w:  [1.2703 1.2336], f(w):  6.160635586013633,
# 87, w:  [4.7742 6.    ], f(w):  14.177707777483853,
#   # Optimal (ls, var) =  (0.8813317840075989, 83.53435970999341)
# 88, w:  [2.4195 0.2302], f(w):  7.8486350316378175,
# 89, w:  [0.3889 3.134 ], f(w):  8.971324837163525,
# 90, w:  [-0.8158  4.8636], f(w):  11.065145742687283,
#   # Optimal (ls, var) =  (0.8815031142480345, 81.2870698982549)
# 91, w:  [ 0.0876 -2.4668], f(w):  7.672621350118732,
# 92, w:  [6.     1.6178], f(w):  13.273271358331444,
# 93, w:  [ 3.248  -2.4672], f(w):  10.867902954254587,
#   # Optimal (ls, var) =  (0.8845496680842411, 79.31636321024105)
# 94, w:  [1.8194 4.6997], f(w):  11.854541286440362,
# 95, w:  [-4.7494 -2.0023], f(w):  11.42406907325543,
# 96, w:  [2.1149 2.3588], f(w):  8.879034656012339,
#   # Optimal (ls, var) =  (0.8867620887898995, 77.14834977888728)
# 97, w:  [ 6.     -0.7993], f(w):  12.301189737967421,
# 98, w:  [ 1.5869 -1.1896], f(w):  6.8249565093924875,
# 99, w:  [-4.9015  0.1646], f(w):  10.782286299825989,
#   # Optimal (ls, var) =  (0.8800793188068159, 75.91918583290908)
# 100, w:  [ 1.4021 -2.6311], f(w):  9.125508499843056,
# 101, w:  [ 0.8649 -4.2117], f(w):  10.262780220999575,
# 102, w:  [-0.9577  2.5732], f(w):  8.119002972289476,
#   # Optimal (ls, var) =  (0.8784940628407579, 77.28060738059533)
# 103, w:  [-2.3117 -2.8888], f(w):  9.652212935723131,
# 104, w:  [ 4.7811 -6.    ], f(w):  14.143361517375363,
# 105, w:  [ 1.0154 -6.    ], f(w):  11.548079647795522,
#   # Optimal (ls, var) =  (0.8775169646624651, 72.45930643898143)
# 106, w:  [-4.9631 -5.202 ], f(w):  13.595705863449885,
# 107, w:  [-3.3394 -3.4857], f(w):  12.14732137418814,
# 108, w:  [-2.8103 -5.2073], f(w):  12.682808195770626,
#   # Optimal (ls, var) =  (0.8788547696599516, 70.97323305317184)
# 109, w:  [4.5936 0.4083], f(w):  11.866446637629002,
# 110, w:  [-4.7888  1.4722], f(w):  12.181312160983163,
# 111, w:  [-3.6345 -0.0327], f(w):  9.585749278554772,
#   # Optimal (ls, var) =  (0.881248242486965, 69.74959265871627)
# 112, w:  [4.113  4.8479], f(w):  12.630017580364113,
# 113, w:  [-0.9995 -6.    ], f(w):  11.538639841302109,
# 114, w:  [ 0.0389 -0.091 ], f(w):  0.5224288321501871,
#   # Optimal (ls, var) =  (0.8575075977213771, 70.49272389533893)
# 115, w:  [-0.4104 -0.28  ], f(w):  3.4784772639839976,
# 116, w:  [-2.2576 -0.6598], f(w):  7.631105623118778,
# 117, w:  [0.7542 0.8702], f(w):  4.296521846996406,
#   # Optimal (ls, var) =  (0.7535593545006211, 77.66043309615404)
# 118, w:  [ 1.5094 -0.3121], f(w):  6.133549691779493,
# 119, w:  [ 2.9969 -0.787 ], f(w):  7.964149708837409,
# 120, w:  [-1.5714  0.194 ], f(w):  5.973579315979524,
#   # Optimal (ls, var) =  (0.7432910221221063, 75.82959760559883)
# 121, w:  [-4.8316  3.5987], f(w):  13.336244589416618,
# 122, w:  [3.6161 1.2502], f(w):  10.387622638714493,
# 123, w:  [-1.9802  5.1741], f(w):  11.516262064419443,
#   # Optimal (ls, var) =  (0.738931508332589, 86.43603624686568)
# 124, w:  [-3.7601  1.8688], f(w):  10.224365501998847,
# 125, w:  [ 6.     -2.8927], f(w):  12.484563393530859,
# 126, w:  [ 4.8687 -3.6979], f(w):  13.098732772833374,
#   # Optimal (ls, var) =  (0.7399305330054922, 78.15444593393482)
# 127, w:  [ 6.     -4.9223], f(w):  13.480394719593438,
# 128, w:  [ 2.7151 -1.5515], f(w):  9.308077078478384,
# 129, w:  [-0.0353 -3.6119], f(w):  9.606031771689034,
#   # Optimal (ls, var) =  (0.7376888509222088, 77.34019006062974)
# 130, w:  [-1.0388  0.754 ], f(w):  4.393553129632263,
# 131, w:  [-3.5153 -1.4642], f(w):  10.672758725617657,
# 132, w:  [-4.8976 -4.0911], f(w):  12.335702977859226,
#   # Optimal (ls, var) =  (0.7374187288519402, 71.1534484252004)
# 133, w:  [ 0.3992 -1.721 ], f(w):  6.529417780507416,
# 134, w:  [4.9965 2.506 ], f(w):  12.645766002735384,
# 135, w:  [ 4.8742 -1.5821], f(w):  12.108814620457967,
#   # Optimal (ls, var) =  (0.7379662674109763, 67.97158464456504)
# 136, w:  [-0.0832 -0.1483], f(w):  1.1149561280858404,
# 137, w:  [ 0.9672 -1.1217], f(w):  4.1576747674417796,
# 138, w:  [-0.2382 -1.1572], f(w):  4.428932398851895,
#   # Optimal (ls, var) =  (0.5898826310898839, 92.93484987245549)
# 139, w:  [0.1591 0.1986], f(w):  1.8892623706001186,
# 140, w:  [-1.0693 -0.1701], f(w):  3.5562398118157543,
# 141, w:  [0.1565 1.0852], f(w):  3.5628574014866925,
#   # Optimal (ls, var) =  (0.4994370664122539, 100.0)
# 142, w:  [ 0.3227 -1.0113], f(w):  4.18538856921332,
# 143, w:  [-0.8018 -0.8257], f(w):  4.247167295959475,
# 144, w:  [-5.253   5.2437], f(w):  14.706919985959745,
#   # Optimal (ls, var) =  (0.49492381917152295, 99.94159862660798)
# 145, w:  [1.0349 0.1337], f(w):  3.187781941739129,
# 146, w:  [-3.4634  5.2729], f(w):  13.950865762363458,
# 147, w:  [-5.2112 -0.7992], f(w):  11.915678989553342,
#   # Optimal (ls, var) =  (0.49671395983014116, 99.99999987223083)
# 148, w:  [-2.5129  2.3117], f(w):  9.87534772778889,
# 149, w:  [-2.5399  3.4321], f(w):  11.39320490979472,
# 150, w:  [3.6778 3.7656], f(w):  12.374382502112667,
#   # Optimal (ls, var) =  (0.4981005458902647, 99.10936944711314)
# 151, w:  [2.7505 5.4407], f(w):  13.644623041449748,
# 152, w:  [-3.8479  3.5259], f(w):  12.342918255205868,
# 153, w:  [0.574  2.1603], f(w):  7.303315197114166,
#   # Optimal (ls, var) =  (0.49941893829185213, 98.20571245306799)
# 154, w:  [-2.364  0.911], f(w):  7.640518238542359,
# 155, w:  [-2.6146 -1.6819], f(w):  9.275096325370885,
# 156, w:  [5.2559 5.1461], f(w):  14.321253292273752,
#   # Optimal (ls, var) =  (0.5001232011661189, 93.82508626476346)
# 157, w:  [ 0.5297 -5.1406], f(w):  12.247979456711363,
# 158, w:  [5.4586 3.506 ], f(w):  14.353471455357568,
# 159, w:  [ 3.9043 -0.5441], f(w):  10.331662282652346,
#   # Optimal (ls, var) =  (0.5014502060445333, 92.81744229591526)
# 160, w:  [1.2192 5.4496], f(w):  12.954480841647952,
# 161, w:  [-1.446   3.7108], f(w):  10.778430331648796,
# 162, w:  [-0.1593  5.3698], f(w):  12.431838802326789,
#   # Optimal (ls, var) =  (0.5034319347759331, 95.14418414745147)
# 163, w:  [0.0982 3.97  ], f(w):  8.855594367595204,
# 164, w:  [ 2.5376 -2.9452], f(w):  10.19221870450814,
# 165, w:  [-3.2439  0.739 ], f(w):  9.239760597201105,
#   # Optimal (ls, var) =  (0.5042524895780004, 94.31707014745018)
# 166, w:  [-1.5922 -2.6676], f(w):  9.31528128168161,
# 167, w:  [2.1635 3.898 ], f(w):  10.137773204473477,
# 168, w:  [ 3.8443 -4.5319], f(w):  13.277890697916865,
#   # Optimal (ls, var) =  (0.5054319486061494, 92.66834000459421)
# 169, w:  [1.8029 1.4922], f(w):  7.639372338612775,
# 170, w:  [ 2.7112 -5.4853], f(w):  13.761276547511947,
# 171, w:  [-4.9459 -6.    ], f(w):  13.416909015740849,
#   # Optimal (ls, var) =  (0.5060344213435538, 91.88936964557422)
# 172, w:  [ 2.0366 -4.45  ], f(w):  11.696569179509828,
# 173, w:  [-0.2084 -0.8243], f(w):  3.5589473644416896,
# 174, w:  [ 1.4452 -3.5381], f(w):  10.684817430666989,
#   # Optimal (ls, var) =  (0.4946650166410039, 92.70172693283357)
# 175, w:  [-5.4144  2.1928], f(w):  13.18746614097345,
# 176, w:  [-1.4367 -1.2182], f(w):  6.699162933055003,
# 177, w:  [-5.4399 -3.4231], f(w):  14.255799350907436,
#   # Optimal (ls, var) =  (0.49572403138160953, 91.54508992357387)
# 178, w:  [-1.6066 -3.6861], f(w):  10.83677434073682,
# 179, w:  [-0.5721  1.8988], f(w):  6.6556158123303035,
# 180, w:  [-6.     -5.1764], f(w):  14.136624136684652,
#   # Optimal (ls, var) =  (0.4963314746962463, 89.21972895863334)
# 181, w:  [-5.3999  0.7898], f(w):  12.719165538909422,
# 182, w:  [-0.7038 -5.2553], f(w):  12.417182079979623,
# 183, w:  [-3.008 -6.   ], f(w):  12.260615107689823,
#   # Optimal (ls, var) =  (0.49805214947383936, 92.12437120369141)
# 184, w:  [-5.5452 -2.1521], f(w):  13.268660349294468,
# 185, w:  [ 2.9857 -3.7863], f(w):  10.763220131417699,
# 186, w:  [-3.0865 -4.3796], f(w):  12.276992431094111,
#   # Optimal (ls, var) =  (0.4984712603872849, 88.94060868555647)
# 187, w:  [-0.9563  0.252 ], f(w):  3.720826207834698,
# 188, w:  [1.2962 2.6637], f(w):  8.893792949500293,
# 189, w:  [-2.047  -5.0627], f(w):  10.91908968024887,
#   # Optimal (ls, var) =  (0.49692703653248715, 84.96898862713293)
# 190, w:  [ 0.7061 -2.3019], f(w):  7.746633929238879,
# 191, w:  [4.1227 2.1564], f(w):  10.471511937241624,
# 192, w:  [ 3.9777 -2.3321], f(w):  11.01714302381354,
#   # Optimal (ls, var) =  (0.49805640351897096, 86.62112819393401)
# 193, w:  [-2.0417  0.187 ], f(w):  5.786346795865338,
# 194, w:  [-4.1077 -2.4438], f(w):  11.621031357573322,
# 195, w:  [5.3041 0.9319], f(w):  12.045802016951413,
#   # Optimal (ls, var) =  (0.4981612805683481, 85.96973498298847)
# 196, w:  [-2.0568  1.4725], f(w):  7.756911488192639,
# 197, w:  [2.9836 0.7412], f(w):  8.17054791948833,
# 198, w:  [2.7383 1.8762], f(w):  8.834913427468821,
#   # Optimal (ls, var) =  (0.49691319714172444, 76.75204566079996)
# 199, w:  [-0.7986 -4.0852], f(w):  9.830349801770133,
# 200, w:  [1.1314 4.0617], f(w):  9.471177546398089,
# 201, w:  [-5.6929  3.5749], f(w):  14.451397319102036,
#   # Optimal (ls, var) =  (0.4998331665640931, 84.9491714568995)
# 202, w:  [-1.9171  6.    ], f(w):  11.967621487049197,
# 203, w:  [-4.0503 -3.8995], f(w):  11.279845619406439,
# 204, w:  [-2.6664  4.8763], f(w):  12.493139664484623,
#   # Optimal (ls, var) =  (0.49985528717939, 82.81957495997486)
# 205, w:  [ 5.3459 -0.0552], f(w):  12.122659443507208,
# 206, w:  [ 2.9426 -0.1673], f(w):  7.489111104928243,
# 207, w:  [-0.5285  0.9495], f(w):  4.584174048346053,
#   # Optimal (ls, var) =  (0.5005646928312757, 81.84333712797604)
# 208, w:  [-1.4082  4.5088], f(w):  12.06458057993645,
# 209, w:  [-0.3946  6.    ], f(w):  13.06154678201108,
# 210, w:  [-2.5376 -2.3148], f(w):  9.909138178656447,
#   # Optimal (ls, var) =  (0.5014855805561186, 82.41899221820512)
# 211, w:  [-0.3408  3.0091], f(w):  8.428043145188973,
# 212, w:  [ 3.9575 -5.3219], f(w):  13.587312197832286,
# 213, w:  [-0.1009 -1.8642], f(w):  5.280616468756882,
#   # Optimal (ls, var) =  (0.5042265150168705, 90.5937353962361)
# 214, w:  [1.9201 0.8797], f(w):  5.652135967036315,
# 215, w:  [-0.2436  4.5062], f(w):  11.534505366612823,
# 216, w:  [-0.3628 -2.9629], f(w):  8.430942805605145,
#   # Optimal (ls, var) =  (0.5024762726656739, 79.3672793977657)
# 217, w:  [ 5.3015 -5.2987], f(w):  15.055419692747439,
# 218, w:  [0.6614 0.4795], f(w):  4.43271405028133,
# 219, w:  [2.0171 3.0513], f(w):  8.153889458008265,
#   # Optimal (ls, var) =  (0.5015002104113702, 77.90324148898172)
# 220, w:  [-4.3038 -0.1415], f(w):  10.679312591644562,
# 221, w:  [-6.      5.1413], f(w):  13.915645766874627,
# 222, w:  [3.46  2.981], f(w):  11.22199236883521,
#   # Optimal (ls, var) =  (0.5022143925002935, 77.80540206560603)
# 223, w:  [0.7347 1.5719], f(w):  6.462321248208735,
# 224, w:  [-2.0807 -1.204 ], f(w):  6.69685965141257,
# 225, w:  [-4.2069 -1.6141], f(w):  11.3590362178318,
#   # Optimal (ls, var) =  (0.5029206015154161, 77.21628994689507)
# 226, w:  [-0.8878 -0.4572], f(w):  4.448757231710513,
# 227, w:  [-0.8717 -1.3074], f(w):  5.518643656550093,
# 228, w:  [-1.4134  1.3646], f(w):  7.101110599520233,
#   # Optimal (ls, var) =  (0.4972690520697953, 78.1438624739247)
# 229, w:  [-5.1325  6.    ], f(w):  13.862280921734483,
# 230, w:  [-6.     -0.6348], f(w):  13.01377482992905,
# 231, w:  [-5.1814  4.375 ], f(w):  14.187597681925169,
#   # Optimal (ls, var) =  (0.4972059705546796, 76.86891270143272)
# 232, w:  [-3.5184  6.    ], f(w):  14.236127522258458,
# 233, w:  [ 5.3272 -4.3699], f(w):  14.607410920967913,
# 234, w:  [ 5.3009 -3.0573], f(w):  12.936069600407805,
#   # Optimal (ls, var) =  (0.4982062162750552, 75.32276049675933)
# 235, w:  [-3.8621  2.6056], f(w):  11.437234218976418,
# 236, w:  [-3.1654  2.1464], f(w):  9.329172102333532,
# 237, w:  [0.4195 0.8882], f(w):  4.3664091876268465,
#   # Optimal (ls, var) =  (0.4894432002783884, 73.71330464240064)
# 238, w:  [-2.9751 -2.9078], f(w):  9.123070547510496,
# 239, w:  [ 4.2595 -3.0747], f(w):  11.687928321660008,
# 240, w:  [-0.7507 -0.0489], f(w):  3.122657039302791,
#   # Optimal (ls, var) =  (0.48623121756177023, 74.02353363660467)
# 241, w:  [-5.0171 -2.6995], f(w):  12.376267189601034,
# 242, w:  [ 2.1487 -0.2481], f(w):  6.635074938197928,
# 243, w:  [1.2155 0.7384], f(w):  5.288491427829225,
#   # Optimal (ls, var) =  (0.48850763250962276, 80.79139828399184)
# 244, w:  [-3.6007 -5.3347], f(w):  14.151114168301309,
# 245, w:  [3.5064 5.1793], f(w):  13.70789036558505,
# 246, w:  [4.4824 3.653 ], f(w):  13.43285200334116,
#   # Optimal (ls, var) =  (0.4873301594526213, 74.32424720509776)
# 247, w:  [ 2.0541 -1.5907], f(w):  7.816240641534536,
# 248, w:  [-5.0199 -1.4176], f(w):  12.0903741731995,
# 249, w:  [6.     3.6362], f(w):  14.115036541204747,
#   # Optimal (ls, var) =  (0.4879140576166607, 73.90211253717612)

# %%
pl.figure(figsize=(13, 8), dpi=80)
pl.plot(np.squeeze(np.array(history_EI)[:, 1]), "-^")
pl.xlabel("cost")
pl.plot(np.minimum.accumulate(np.array(history_EI)[:, 1]), 'r', lw=1)
pl.ylabel("function value")
pl.grid(True)
# Out:
# <ipython-input-38-a742015083ae>:2: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   pl.plot(np.squeeze(np.array(history_EI)[:, 1]), "-^")
# <ipython-input-38-a742015083ae>:4: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   pl.plot(np.minimum.accumulate(np.array(history_EI)[:, 1]), 'r', lw=1)

# %% [markdown]
# # Comparison

# %%
pl.figure(figsize=(10, 7), dpi=80)
pl.plot(np.minimum.accumulate(np.array(history_ucb)[:, 1]), 'r', lw=2, label='UCB')
pl.plot(np.minimum.accumulate(np.array(history_EI)[:, 1]), 'b', lw=2, label='EI')
pl.plot(np.minimum.accumulate(np.array(history)[:, 1]), 'g', lw=2, label='GD-UCB')
pl.legend()
# Out:
# <ipython-input-40-372a34bd46ca>:2: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   pl.plot(np.minimum.accumulate(np.array(history_ucb)[:, 1]), 'r', lw=2, label='UCB')
# <ipython-input-40-372a34bd46ca>:3: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   pl.plot(np.minimum.accumulate(np.array(history_EI)[:, 1]), 'b', lw=2, label='EI')
# <ipython-input-40-372a34bd46ca>:4: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   pl.plot(np.minimum.accumulate(np.array(history)[:, 1]), 'g', lw=2, label='GD-UCB')
